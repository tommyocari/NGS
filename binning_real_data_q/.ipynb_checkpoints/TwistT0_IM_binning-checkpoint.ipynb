# %%
import numpy as np
import pandas as pd
import torch

import sys
sys.path.append('../')
from utilities import binning_equal_q

# %%
def infer_fields(data, counts):
    
    fields = np.zeros([7,20])
    for pos in range(7):
        for color in range(20):
            fields[pos,color] = (counts*((data[:,pos] == color).astype('int'))).sum() 

    print(counts.sum(), fields.sum(1))

    fields = fields[:,:] / fields[:,0][:,np.newaxis]
    return torch.tensor(np.log(fields))

def sorted_log10p_vector_from_fields(fields):
    
    lengths = [torch.arange(20, dtype=torch.int8) for i in range(7)]
    all_seq = torch.cartesian_prod(*lengths)
    
    all_seq = all_seq.long()
    
    # generate p_vector
    p_vector = torch.zeros(20**7,dtype=torch.float32)

    for i in range(7):
        p_vector += fields[i,all_seq[:,i]]
        print(i)
    
    p_vector = torch.exp(p_vector)
    
    Z = torch.exp(fields).sum(1).prod()
    
    p_vector /= Z
    print(p_vector.sum())
    
    return torch.log(p_vector).sort()[0] / np.log(10)

def log10q_vector_func(data, fields):
    
    # generate q_vector
    q_vector = torch.zeros(len(data))

    for i in range(7):
        q_vector += fields[i,data[:,i]]
        print(i)

    q_vector = torch.exp(q_vector)

    Z = torch.exp(fields).sum(1).prod()

    q_vector /= Z

    print(q_vector.sum())
    return np.log10(q_vector.numpy())

# %%
data = pd.read_csv('../data/Byrne.csv',index_col=0).query('T0 > 0')
data = data.sort_values('T0', ascending=False)
data = data.iloc[1:,:]

counts = data['T0'].to_numpy()
data = data.iloc[:,:7].to_numpy()

# %%
fields = infer_fields(data, counts)
# Out:
# 12195473 [12195473. 12195473. 12195473. 12195473. 12195473. 12195473. 12195473.]

# %%
sorted_log10p_vector = sorted_log10p_vector_from_fields(fields)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# tensor(1.)

# %%
log10q_vector = log10q_vector_func(data, fields)
argsort = np.argsort(log10q_vector)
sorted_log10q_vector = log10q_vector[argsort][::-1]
counts = counts[argsort][::-1]
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# tensor(0.0130)

# %%
bins=80
df_bins = binning_equal_q(sorted_log10p_vector, sorted_log10q_vector, counts, bins=bins, writefolder='results_ByrneT0_IM', step=1)
df_bins.to_csv('df_bins_Byrne_IM_%dbins.csv'%bins)
# Out:
# 0
# tensor(1279999999) tensor(1279655622)
# elements in the bin: 344377
# nonzeros: 38393
# 1
# tensor(1279655622) tensor(1279137703)
# elements in the bin: 517919
# nonzeros: 38393
# 2
# tensor(1279137703) tensor(1278496952)
# elements in the bin: 640751
# nonzeros: 38393
# 3
# tensor(1278496952) tensor(1277748115)
# elements in the bin: 748837
# nonzeros: 38393
# 4
# tensor(1277748115) tensor(1276900422)
# elements in the bin: 847693
# nonzeros: 38393
# 5
# tensor(1276900422) tensor(1275940685)
# elements in the bin: 959737
# nonzeros: 38393
# 6
# tensor(1275940685) tensor(1274897010)
# elements in the bin: 1043675
# nonzeros: 38393
# 7
# tensor(1274897010) tensor(1273747624)
# elements in the bin: 1149386
# nonzeros: 38393
# 8
# tensor(1273747624) tensor(1272505426)
# elements in the bin: 1242198
# nonzeros: 38393
# 9
# tensor(1272505426) tensor(1271170602)
# elements in the bin: 1334824
# nonzeros: 38393
# 10
# tensor(1271170602) tensor(1269745267)
# elements in the bin: 1425335
# nonzeros: 38393
# 11
# tensor(1269745267) tensor(1268216095)
# elements in the bin: 1529172
# nonzeros: 38393
# 12
# tensor(1268216095) tensor(1266565340)
# elements in the bin: 1650755
# nonzeros: 38393
# 13
# tensor(1266565340) tensor(1264840393)
# elements in the bin: 1724947
# nonzeros: 38393
# 14
# tensor(1264840393) tensor(1263009989)
# elements in the bin: 1830404
# nonzeros: 38393
# 15
# tensor(1263009989) tensor(1261078802)
# elements in the bin: 1931187
# nonzeros: 38393
# 16
# tensor(1261078802) tensor(1259036168)
# elements in the bin: 2042634
# nonzeros: 38393
# 17
# tensor(1259036168) tensor(1256875136)
# elements in the bin: 2161032
# nonzeros: 38393
# 18
# tensor(1256875136) tensor(1254594886)
# elements in the bin: 2280250
# nonzeros: 38393
# 19
# tensor(1254594886) tensor(1252200579)
# elements in the bin: 2394307
# nonzeros: 38393
# 20
# tensor(1252200579) tensor(1249692083)
# elements in the bin: 2508496
# nonzeros: 38393
# 21
# tensor(1249692083) tensor(1247080246)
# elements in the bin: 2611837
# nonzeros: 38393
# 22
# tensor(1247080246) tensor(1244338428)
# elements in the bin: 2741818
# nonzeros: 38393
# 23
# tensor(1244338428) tensor(1241421294)
# elements in the bin: 2917134
# nonzeros: 38393
# 24
# tensor(1241421294) tensor(1238388173)
# elements in the bin: 3033121
# nonzeros: 38393
# 25
# tensor(1238388173) tensor(1235207928)
# elements in the bin: 3180245
# nonzeros: 38393
# 26
# tensor(1235207928) tensor(1231893448)
# elements in the bin: 3314480
# nonzeros: 38393
# 27
# tensor(1231893448) tensor(1228456257)
# elements in the bin: 3437191
# nonzeros: 38393
# 28
# tensor(1228456257) tensor(1224819095)
# elements in the bin: 3637162
# nonzeros: 38393
# 29
# tensor(1224819095) tensor(1221008648)
# elements in the bin: 3810447
# nonzeros: 38393
# 30
# tensor(1221008648) tensor(1217072731)
# elements in the bin: 3935917
# nonzeros: 38393
# 31
# tensor(1217072731) tensor(1212952532)
# elements in the bin: 4120199
# nonzeros: 38393
# 32
# tensor(1212952532) tensor(1208590551)
# elements in the bin: 4361981
# nonzeros: 38393
# 33
# tensor(1208590551) tensor(1204103773)
# elements in the bin: 4486778
# nonzeros: 38393
# 34
# tensor(1204103773) tensor(1199444716)
# elements in the bin: 4659057
# nonzeros: 38393
# 35
# tensor(1199444716) tensor(1194564296)
# elements in the bin: 4880420
# nonzeros: 38393
# 36
# tensor(1194564296) tensor(1189399624)
# elements in the bin: 5164672
# nonzeros: 38393
# 37
# tensor(1189399624) tensor(1183999899)
# elements in the bin: 5399725
# nonzeros: 38393
# 38
# tensor(1183999899) tensor(1178408307)
# elements in the bin: 5591592
# nonzeros: 38393
# 39
# tensor(1178408307) tensor(1172549943)
# elements in the bin: 5858364
# nonzeros: 38393
# 40
# tensor(1172549943) tensor(1166382277)
# elements in the bin: 6167666
# nonzeros: 38393
# 41
# tensor(1166382277) tensor(1160027933)
# elements in the bin: 6354344
# nonzeros: 38393
# 42
# tensor(1160027933) tensor(1153349407)
# elements in the bin: 6678526
# nonzeros: 38393
# 43
# tensor(1153349407) tensor(1146322609)
# elements in the bin: 7026798
# nonzeros: 38393
# 44
# tensor(1146322609) tensor(1139053903)
# elements in the bin: 7268706
# nonzeros: 38393
# 45
# tensor(1139053903) tensor(1131393147)
# elements in the bin: 7660756
# nonzeros: 38393
# 46
# tensor(1131393147) tensor(1123420229)
# elements in the bin: 7972918
# nonzeros: 38393
# 47
# tensor(1123420229) tensor(1114977398)
# elements in the bin: 8442831
# nonzeros: 38393
# 48
# tensor(1114977398) tensor(1106173046)
# elements in the bin: 8804352
# nonzeros: 38393
# 49
# tensor(1106173046) tensor(1096977686)
# elements in the bin: 9195360
# nonzeros: 38393
# 50
# tensor(1096977686) tensor(1087315473)
# elements in the bin: 9662213
# nonzeros: 38393
# 51
# tensor(1087315473) tensor(1077246685)
# elements in the bin: 10068788
# nonzeros: 38393
# 52
# tensor(1077246685) tensor(1066556440)
# elements in the bin: 10690245
# nonzeros: 38393
# 53
# tensor(1066556440) tensor(1055237339)
# elements in the bin: 11319101
# nonzeros: 38393
# 54
# tensor(1055237339) tensor(1043478892)
# elements in the bin: 11758447
# nonzeros: 38393
# 55
# tensor(1043478892) tensor(1031094786)
# elements in the bin: 12384106
# nonzeros: 38393
# 56
# tensor(1031094786) tensor(1017925275)
# elements in the bin: 13169511
# nonzeros: 38393
# 57
# tensor(1017925275) tensor(1004060941)
# elements in the bin: 13864334
# nonzeros: 38393
# 58
# tensor(1004060941) tensor(989447934)
# elements in the bin: 14613007
# nonzeros: 38393
# 59
# tensor(989447934) tensor(973728357)
# elements in the bin: 15719577
# nonzeros: 38393
# 60
# tensor(973728357) tensor(957254423)
# elements in the bin: 16473934
# nonzeros: 38393
# 61
# tensor(957254423) tensor(939803785)
# elements in the bin: 17450638
# nonzeros: 38393
# 62
# tensor(939803785) tensor(921099683)
# elements in the bin: 18704102
# nonzeros: 38393
# 63
# tensor(921099683) tensor(901254542)
# elements in the bin: 19845141
# nonzeros: 38393
# 64
# tensor(901254542) tensor(879782319)
# elements in the bin: 21472223
# nonzeros: 38393
# 65
# tensor(879782319) tensor(856846650)
# elements in the bin: 22935669
# nonzeros: 38393
# 66
# tensor(856846650) tensor(832150059)
# elements in the bin: 24696591
# nonzeros: 38393
# 67
# tensor(832150059) tensor(805479402)
# elements in the bin: 26670657
# nonzeros: 38393
# 68
# tensor(805479402) tensor(776880830)
# elements in the bin: 28598572
# nonzeros: 38393
# 69
# tensor(776880830) tensor(745536958)
# elements in the bin: 31343872
# nonzeros: 38393
# 70
# tensor(745536958) tensor(711358340)
# elements in the bin: 34178618
# nonzeros: 38393
# 71
# tensor(711358340) tensor(673991715)
# elements in the bin: 37366625
# nonzeros: 38393
# 72
# tensor(673991715) tensor(632480147)
# elements in the bin: 41511568
# nonzeros: 38393
# 73
# tensor(632480147) tensor(586042640)
# elements in the bin: 46437507
# nonzeros: 38393
# 74
# tensor(586042640) tensor(533694222)
# elements in the bin: 52348418
# nonzeros: 38393
# 75
# tensor(533694222) tensor(473160083)
# elements in the bin: 60534139
# nonzeros: 38393
# 76
# tensor(473160083) tensor(403135860)
# elements in the bin: 70024223
# nonzeros: 38393
# 77
# tensor(403135860) tensor(317333887)
# elements in the bin: 85801973
# nonzeros: 38393
# 78
# tensor(317333887) tensor(206207489)
# elements in the bin: 111126398
# nonzeros: 38393
# 79
# tensor(206207489) tensor(107619)
# elements in the bin: 206099870
# nonzeros: 38403

# %% [markdown]
# ## Write down F

# %%
df_bins = pd.read_csv('df_bins_Byrne_IM_80bins.csv',index_col=0)
F_vec = np.zeros(2)
F_vec[0] = ((df_bins['var_count'] - df_bins['var_lambda']) / df_bins['mean_count']).mean()
F_vec[1] = ((df_bins['var_count'] - df_bins['var_lambda']) / df_bins['mean_count']).std()
np.savetxt('F_Byrne.csv',F_vec,delimiter=',')
F_vec
# Out:
# array([8.92247337, 0.44065842])
