# %%
import numpy as np
import pandas as pd
import torch

import sys
sys.path.append('../')
from utilities import binning_equal_q

# %%
def infer_fields(data, counts):
    
    fields = np.zeros([7,16])
    for pos in range(7):
        for color in range(16):
            fields[pos,color] = (counts*((data[:,pos] == color).astype('int'))).sum() 

    print(counts.sum(), fields.sum(1))

    fields7 = fields[6,:][fields[6,:] > 0]
    fields7 = torch.tensor(np.log(fields7 / fields7[0]))
    fields = fields[:6,:] / fields[:6,0][:,np.newaxis]
    fields = torch.tensor(np.log(fields))
    
    return fields, fields7

def sorted_log10p_vector_from_fields(fields, fields7):
    
    lengths = [torch.arange(16, dtype=torch.int8) for i in range(6)]
    lengths.append(torch.arange(11, dtype=torch.int8))
    all_seq = torch.cartesian_prod(*lengths)
    
    all_seq = all_seq.long()
    
    # generate p_vector
    p_vector = torch.zeros(11*16**6,dtype=torch.float32)

    for i in range(6):
        p_vector += fields[i,all_seq[:,i]]
        print(i)
    p_vector += fields7[all_seq[:,6]]
    
    p_vector = torch.exp(p_vector)
    
    Z = torch.exp(fields).sum(1).prod() * torch.exp(fields7).sum()
    
    p_vector /= Z
    print(p_vector.sum())
    
    return torch.log(p_vector).sort()[0] / np.log(10)

def log10q_vector_func(data, fields, fields7):
    
    # generate q_vector
    q_vector = torch.zeros(len(data))

    for i in range(6):
        q_vector += fields[i,data[:,i]]
        print(i)
    q_vector += fields7[data[:,6]]

    q_vector = torch.exp(q_vector)

    Z = torch.exp(fields).sum(1).prod() * torch.exp(fields7).sum()

    q_vector /= Z

    print(q_vector.sum())
    return np.log10(q_vector.numpy())

# %%
t = 16

# %%
data = pd.read_csv('../data/Dalkara.csv',index_col=0).query('T0 > 0')

transform_dict = {np.unique(data['a7'])[i] : i for i in range(11)}
data['a7'] = data['a7'].replace(transform_dict)

data = data.sort_values('T0', ascending=False)

np.random.seed(0)
data['sample'] = np.random.binomial(data['T0'], p=np.array([1./t]))
data = data.query('sample > 0')

counts = data['sample'].to_numpy()
data = data.iloc[:,:7].to_numpy()

# %%
fields, fields7 = infer_fields(data, counts)
# Out:
# 853257 [853257. 853257. 853257. 853257. 853257. 853257. 853257.]

# %%
sorted_log10p_vector = sorted_log10p_vector_from_fields(fields, fields7)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# tensor(1.)

# %%
log10q_vector = log10q_vector_func(data, fields, fields7)
argsort = np.argsort(log10q_vector)
sorted_log10q_vector = log10q_vector[argsort][::-1]
counts = counts[argsort][::-1]
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# tensor(0.6149)

# %%
bins=200
df_bins = binning_equal_q(sorted_log10p_vector, log10q_vector, counts, bins=bins, writefolder=False)#'results_DalkaraT0_IM', step=1000)
df_bins.to_csv('df_bins_Dalkara_IM_%dt.csv'%t)
# Out:
# 0
# tensor(184549371) tensor(184546259)
# elements in the bin: 3112
# nonzeros: 1852
# 1
# tensor(184546259) tensor(184545519)
# elements in the bin: 740
# nonzeros: 1852
# 2
# tensor(184545519) tensor(184545224)
# elements in the bin: 295
# nonzeros: 1852
# 3
# tensor(184545224) tensor(184541493)
# elements in the bin: 3731
# nonzeros: 1852
# 4
# tensor(184541493) tensor(184542912)
# elements in the bin: 0
# nonzeros: 1852
# 5
# tensor(184542912) tensor(184532543)
# elements in the bin: 10369
# nonzeros: 1852
# 6
# tensor(184532543) tensor(184532292)
# elements in the bin: 251
# nonzeros: 1852
# 7
# tensor(184532292) tensor(184526318)
# elements in the bin: 5974
# nonzeros: 1852
# 8
# tensor(184526318) tensor(184529625)
# elements in the bin: 0
# nonzeros: 1852
# 9
# tensor(184529625) tensor(184508227)
# elements in the bin: 21398
# nonzeros: 1852
# 10
# tensor(184508227) tensor(184490435)
# elements in the bin: 17792
# nonzeros: 1852
# 11
# tensor(184490435) tensor(184515082)
# elements in the bin: 0
# nonzeros: 1852
# 12
# tensor(184515082) tensor(184520864)
# elements in the bin: 0
# nonzeros: 1852
# 13
# tensor(184520864) tensor(184507794)
# elements in the bin: 13070
# nonzeros: 1852
# 14
# tensor(184507794) tensor(184517130)
# elements in the bin: 0
# nonzeros: 1852
# 15
# tensor(184517130) tensor(184521618)
# elements in the bin: 0
# nonzeros: 1852
# 16
# tensor(184521618) tensor(184494168)
# elements in the bin: 27450
# nonzeros: 1852
# 17
# tensor(184494168) tensor(184509600)
# elements in the bin: 0
# nonzeros: 1852
# 18
# tensor(184509600) tensor(184521070)
# elements in the bin: 0
# nonzeros: 1852
# 19
# tensor(184521070) tensor(184514129)
# elements in the bin: 6941
# nonzeros: 1852
# 20
# tensor(184514129) tensor(184513164)
# elements in the bin: 965
# nonzeros: 1852
# 21
# tensor(184513164) tensor(184504534)
# elements in the bin: 8630
# nonzeros: 1852
# 22
# tensor(184504534) tensor(184449388)
# elements in the bin: 55146
# nonzeros: 1852
# 23
# tensor(184449388) tensor(184508161)
# elements in the bin: 0
# nonzeros: 1852
# 24
# tensor(184508161) tensor(184492424)
# elements in the bin: 15737
# nonzeros: 1852
# 25
# tensor(184492424) tensor(184507875)
# elements in the bin: 0
# nonzeros: 1852
# 26
# tensor(184507875) tensor(184506302)
# elements in the bin: 1573
# nonzeros: 1852
# 27
# tensor(184506302) tensor(184484240)
# elements in the bin: 22062
# nonzeros: 1852
# 28
# tensor(184484240) tensor(184509767)
# elements in the bin: 0
# nonzeros: 1852
# 29
# tensor(184509767) tensor(184519652)
# elements in the bin: 0
# nonzeros: 1852
# 30
# tensor(184519652) tensor(184507063)
# elements in the bin: 12589
# nonzeros: 1852
# 31
# tensor(184507063) tensor(184462341)
# elements in the bin: 44722
# nonzeros: 1852
# 32
# tensor(184462341) tensor(184474476)
# elements in the bin: 0
# nonzeros: 1852
# 33
# tensor(184474476) tensor(184475502)
# elements in the bin: 0
# nonzeros: 1852
# 34
# tensor(184475502) tensor(184515320)
# elements in the bin: 0
# nonzeros: 1852
# 35
# tensor(184515320) tensor(184466771)
# elements in the bin: 48549
# nonzeros: 1852
# 36
# tensor(184466771) tensor(184383037)
# elements in the bin: 83734
# nonzeros: 1852
# 37
# tensor(184383037) tensor(184344448)
# elements in the bin: 38589
# nonzeros: 1852
# 38
# tensor(184344448) tensor(184371621)
# elements in the bin: 0
# nonzeros: 1852
# 39
# tensor(184371621) tensor(184375866)
# elements in the bin: 0
# nonzeros: 1852
# 40
# tensor(184375866) tensor(184500906)
# elements in the bin: 0
# nonzeros: 1852
# 41
# tensor(184500906) tensor(184459195)
# elements in the bin: 41711
# nonzeros: 1852
# 42
# tensor(184459195) tensor(184404212)
# elements in the bin: 54983
# nonzeros: 1852
# 43
# tensor(184404212) tensor(184448215)
# elements in the bin: 0
# nonzeros: 1852
# 44
# tensor(184448215) tensor(184446330)
# elements in the bin: 1885
# nonzeros: 1852
# 45
# tensor(184446330) tensor(184460166)
# elements in the bin: 0
# nonzeros: 1852
# 46
# tensor(184460166) tensor(184315277)
# elements in the bin: 144889
# nonzeros: 1852
# 47
# tensor(184315277) tensor(184373279)
# elements in the bin: 0
# nonzeros: 1852
# 48
# tensor(184373279) tensor(184518890)
# elements in the bin: 0
# nonzeros: 1852
# 49
# tensor(184518890) tensor(183769622)
# elements in the bin: 749268
# nonzeros: 1852
# 50
# tensor(183769622) tensor(184293728)
# elements in the bin: 0
# nonzeros: 1852
# 51
# tensor(184293728) tensor(183325719)
# elements in the bin: 968009
# nonzeros: 1852
# 52
# tensor(183325719) tensor(184369797)
# elements in the bin: 0
# nonzeros: 1852
# 53
# tensor(184369797) tensor(184127197)
# elements in the bin: 242600
# nonzeros: 1852
# 54
# tensor(184127197) tensor(184333591)
# elements in the bin: 0
# nonzeros: 1852
# 55
# tensor(184333591) tensor(184429003)
# elements in the bin: 0
# nonzeros: 1852
# 56
# tensor(184429003) tensor(184230526)
# elements in the bin: 198477
# nonzeros: 1852
# 57
# tensor(184230526) tensor(184424496)
# elements in the bin: 0
# nonzeros: 1852
# 58
# tensor(184424496) tensor(184407116)
# elements in the bin: 17380
# nonzeros: 1852
# 59
# tensor(184407116) tensor(183936315)
# elements in the bin: 470801
# nonzeros: 1852
# 60
# tensor(183936315) tensor(184456175)
# elements in the bin: 0
# nonzeros: 1852
# 61
# tensor(184456175) tensor(184312830)
# elements in the bin: 143345
# nonzeros: 1852
# 62
# tensor(184312830) tensor(184416962)
# elements in the bin: 0
# nonzeros: 1852
# 63
# tensor(184416962) tensor(184452923)
# elements in the bin: 0
# nonzeros: 1852
# 64
# tensor(184452923) tensor(184374363)
# elements in the bin: 78560
# nonzeros: 1852
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# 65
# tensor(184374363) tensor(184430368)
# elements in the bin: 0
# nonzeros: 1852
# 66
# tensor(184430368) tensor(184335813)
# elements in the bin: 94555
# nonzeros: 1852
# 67
# tensor(184335813) tensor(184271663)
# elements in the bin: 64150
# nonzeros: 1852
# 68
# tensor(184271663) tensor(183891800)
# elements in the bin: 379863
# nonzeros: 1852
# 69
# tensor(183891800) tensor(184436762)
# elements in the bin: 0
# nonzeros: 1852
# 70
# tensor(184436762) tensor(184118241)
# elements in the bin: 318521
# nonzeros: 1852
# 71
# tensor(184118241) tensor(184417393)
# elements in the bin: 0
# nonzeros: 1852
# 72
# tensor(184417393) tensor(184348180)
# elements in the bin: 69213
# nonzeros: 1852
# 73
# tensor(184348180) tensor(183291210)
# elements in the bin: 1056970
# nonzeros: 1852
# 74
# tensor(183291210) tensor(184419996)
# elements in the bin: 0
# nonzeros: 1852
# 75
# tensor(184419996) tensor(184340885)
# elements in the bin: 79111
# nonzeros: 1852
# 76
# tensor(184340885) tensor(184460673)
# elements in the bin: 0
# nonzeros: 1852
# 77
# tensor(184460673) tensor(154966365)
# elements in the bin: 29494308
# nonzeros: 1852
# 78
# tensor(154966365) tensor(173696010)
# elements in the bin: 0
# nonzeros: 1852
# 79
# tensor(173696010) tensor(184344302)
# elements in the bin: 0
# nonzeros: 1852
# 80
# tensor(184344302) tensor(171563559)
# elements in the bin: 12780743
# nonzeros: 1852
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# 81
# tensor(171563559) tensor(184232856)
# elements in the bin: 0
# nonzeros: 1852
# 82
# tensor(184232856) tensor(184411559)
# elements in the bin: 0
# nonzeros: 1852
# 83
# tensor(184411559) tensor(184114481)
# elements in the bin: 297078
# nonzeros: 1852
# 84
# tensor(184114481) tensor(184331930)
# elements in the bin: 0
# nonzeros: 1852
# 85
# tensor(184331930) tensor(184448854)
# elements in the bin: 0
# nonzeros: 1852
# 86
# tensor(184448854) tensor(182018230)
# elements in the bin: 2430624
# nonzeros: 1852
# 87
# tensor(182018230) tensor(184032649)
# elements in the bin: 0
# nonzeros: 1852
# 88
# tensor(184032649) tensor(183619205)
# elements in the bin: 413444
# nonzeros: 1852
# 89
# tensor(183619205) tensor(180948755)
# elements in the bin: 2670450
# nonzeros: 1852
# 90
# tensor(180948755) tensor(179164016)
# elements in the bin: 1784739
# nonzeros: 1852
# 91
# tensor(179164016) tensor(184124710)
# elements in the bin: 0
# nonzeros: 1852
# 92
# tensor(184124710) tensor(182825964)
# elements in the bin: 1298746
# nonzeros: 1852
# 93
# tensor(182825964) tensor(184371243)
# elements in the bin: 0
# nonzeros: 1852
# 94
# tensor(184371243) tensor(184437624)
# elements in the bin: 0
# nonzeros: 1852
# 95
# tensor(184437624) tensor(183906313)
# elements in the bin: 531311
# nonzeros: 1852
# 96
# tensor(183906313) tensor(184331382)
# elements in the bin: 0
# nonzeros: 1852
# 97
# tensor(184331382) tensor(167175875)
# elements in the bin: 17155507
# nonzeros: 1852
# 98
# tensor(167175875) tensor(184260194)
# elements in the bin: 0
# nonzeros: 1852
# 99
# tensor(184260194) tensor(181638767)
# elements in the bin: 2621427
# nonzeros: 1852
# 100
# tensor(181638767) tensor(176402112)
# elements in the bin: 5236655
# nonzeros: 1852
# 101
# tensor(176402112) tensor(183895941)
# elements in the bin: 0
# nonzeros: 1852
# 102
# tensor(183895941) tensor(183186907)
# elements in the bin: 709034
# nonzeros: 1852
# 103
# tensor(183186907) tensor(182257164)
# elements in the bin: 929743
# nonzeros: 1852
# 104
# tensor(182257164) tensor(184098777)
# elements in the bin: 0
# nonzeros: 1852
# 105
# tensor(184098777) tensor(183719236)
# elements in the bin: 379541
# nonzeros: 1852
# 106
# tensor(183719236) tensor(183773503)
# elements in the bin: 0
# nonzeros: 1852
# 107
# tensor(183773503) tensor(179074109)
# elements in the bin: 4699394
# nonzeros: 1852
# 108
# tensor(179074109) tensor(184141965)
# elements in the bin: 0
# nonzeros: 1852
# 109
# tensor(184141965) tensor(181600967)
# elements in the bin: 2540998
# nonzeros: 1852
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# 110
# tensor(181600967) tensor(184356689)
# elements in the bin: 0
# nonzeros: 1852
# 111
# tensor(184356689) tensor(136326565)
# elements in the bin: 48030124
# nonzeros: 1852
# 112
# tensor(136326565) tensor(173133334)
# elements in the bin: 0
# nonzeros: 1852
# 113
# tensor(173133334) tensor(182214138)
# elements in the bin: 0
# nonzeros: 1852
# 114
# tensor(182214138) tensor(182685384)
# elements in the bin: 0
# nonzeros: 1852
# 115
# tensor(182685384) tensor(184037663)
# elements in the bin: 0
# nonzeros: 1852
# 116
# tensor(184037663) tensor(180441485)
# elements in the bin: 3596178
# nonzeros: 1852
# 117
# tensor(180441485) tensor(183239766)
# elements in the bin: 0
# nonzeros: 1852
# 118
# tensor(183239766) tensor(179116458)
# elements in the bin: 4123308
# nonzeros: 1852
# 119
# tensor(179116458) tensor(184405818)
# elements in the bin: 0
# nonzeros: 1852
# 120
# tensor(184405818) tensor(184393226)
# elements in the bin: 12592
# nonzeros: 1852
# 121
# tensor(184393226) tensor(184104445)
# elements in the bin: 288781
# nonzeros: 1852
# 122
# tensor(184104445) tensor(184189174)
# elements in the bin: 0
# nonzeros: 1852
# 123
# tensor(184189174) tensor(184439315)
# elements in the bin: 0
# nonzeros: 1852
# 124
# tensor(184439315) tensor(183604475)
# elements in the bin: 834840
# nonzeros: 1852
# 125
# tensor(183604475) tensor(184295502)
# elements in the bin: 0
# nonzeros: 1852
# 126
# tensor(184295502) tensor(182249568)
# elements in the bin: 2045934
# nonzeros: 1852
# 127
# tensor(182249568) tensor(183903413)
# elements in the bin: 0
# nonzeros: 1852
# 128
# tensor(183903413) tensor(184095134)
# elements in the bin: 0
# nonzeros: 1852
# 129
# tensor(184095134) tensor(184192957)
# elements in the bin: 0
# nonzeros: 1852
# 130
# tensor(184192957) tensor(184419389)
# elements in the bin: 0
# nonzeros: 1852
# 131
# tensor(184419389) tensor(183293003)
# elements in the bin: 1126386
# nonzeros: 1852
# 132
# tensor(183293003) tensor(184313823)
# elements in the bin: 0
# nonzeros: 1852
# 133
# tensor(184313823) tensor(184138421)
# elements in the bin: 175402
# nonzeros: 1852
# 134
# tensor(184138421) tensor(178836412)
# elements in the bin: 5302009
# nonzeros: 1852
# 135
# tensor(178836412) tensor(184343308)
# elements in the bin: 0
# nonzeros: 1852
# 136
# tensor(184343308) tensor(183588975)
# elements in the bin: 754333
# nonzeros: 1852
# 137
# tensor(183588975) tensor(184169349)
# elements in the bin: 0
# nonzeros: 1852
# 138
# tensor(184169349) tensor(183312098)
# elements in the bin: 857251
# nonzeros: 1852
# 139
# tensor(183312098) tensor(178691610)
# elements in the bin: 4620488
# nonzeros: 1852
# 140
# tensor(178691610) tensor(173891029)
# elements in the bin: 4800581
# nonzeros: 1852
# 141
# tensor(173891029) tensor(182940914)
# elements in the bin: 0
# nonzeros: 1852
# 142
# tensor(182940914) tensor(173102306)
# elements in the bin: 9838608
# nonzeros: 1852
# 143
# tensor(173102306) tensor(183407498)
# elements in the bin: 0
# nonzeros: 1852
# 144
# tensor(183407498) tensor(182468944)
# elements in the bin: 938554
# nonzeros: 1852
# 145
# tensor(182468944) tensor(181423407)
# elements in the bin: 1045537
# nonzeros: 1852
# 146
# tensor(181423407) tensor(181913906)
# elements in the bin: 0
# nonzeros: 1852
# 147
# tensor(181913906) tensor(157802291)
# elements in the bin: 24111615
# nonzeros: 1852
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
# ...
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# 164
# tensor(181447690) tensor(183524340)
# elements in the bin: 0
# nonzeros: 1852
# 165
# tensor(183524340) tensor(179002944)
# elements in the bin: 4521396
# nonzeros: 1852
# 166
# tensor(179002944) tensor(184394486)
# elements in the bin: 0
# nonzeros: 1852
# 167
# tensor(184394486) tensor(183292743)
# elements in the bin: 1101743
# nonzeros: 1852
# 168
# tensor(183292743) tensor(183444478)
# elements in the bin: 0
# nonzeros: 1852
# 169
# tensor(183444478) tensor(183903849)
# elements in the bin: 0
# nonzeros: 1852
# 170
# tensor(183903849) tensor(184217795)
# elements in the bin: 0
# nonzeros: 1852
# 171
# tensor(184217795) tensor(179143250)
# elements in the bin: 5074545
# nonzeros: 1852
# 172
# tensor(179143250) tensor(179419363)
# elements in the bin: 0
# nonzeros: 1852
# 173
# tensor(179419363) tensor(184188945)
# elements in the bin: 0
# nonzeros: 1852
# 174
# tensor(184188945) tensor(183712926)
# elements in the bin: 476019
# nonzeros: 1852
# 175
# tensor(183712926) tensor(183547718)
# elements in the bin: 165208
# nonzeros: 1852
# 176
# tensor(183547718) tensor(184137808)
# elements in the bin: 0
# nonzeros: 1852
# 177
# tensor(184137808) tensor(180276877)
# elements in the bin: 3860931
# nonzeros: 1852
# 178
# tensor(180276877) tensor(184355377)
# elements in the bin: 0
# nonzeros: 1852
# 179
# tensor(184355377) tensor(178610766)
# elements in the bin: 5744611
# nonzeros: 1852
# 180
# tensor(178610766) tensor(183997566)
# elements in the bin: 0
# nonzeros: 1852
# 181
# tensor(183997566) tensor(180258893)
# elements in the bin: 3738673
# nonzeros: 1852
# 182
# tensor(180258893) tensor(183703607)
# elements in the bin: 0
# nonzeros: 1852
# 183
# tensor(183703607) tensor(182341008)
# elements in the bin: 1362599
# nonzeros: 1852
# 184
# tensor(182341008) tensor(183078423)
# elements in the bin: 0
# nonzeros: 1852
# 185
# tensor(183078423) tensor(129513004)
# elements in the bin: 53565419
# nonzeros: 1852
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# 186
# tensor(129513004) tensor(183825356)
# elements in the bin: 0
# nonzeros: 1852
# 187
# tensor(183825356) tensor(181855150)
# elements in the bin: 1970206
# nonzeros: 1852
# 188
# tensor(181855150) tensor(181675427)
# elements in the bin: 179723
# nonzeros: 1852
# 189
# tensor(181675427) tensor(184187205)
# elements in the bin: 0
# nonzeros: 1852
# 190
# tensor(184187205) tensor(181170631)
# elements in the bin: 3016574
# nonzeros: 1852
# 191
# tensor(181170631) tensor(183322631)
# elements in the bin: 0
# nonzeros: 1852
# 192
# tensor(183322631) tensor(184322856)
# elements in the bin: 0
# nonzeros: 1852
# 193
# tensor(184322856) tensor(160217056)
# elements in the bin: 24105800
# nonzeros: 1852
# 194
# tensor(160217056) tensor(182237787)
# elements in the bin: 0
# nonzeros: 1852
# 195
# tensor(182237787) tensor(176599704)
# elements in the bin: 5638083
# nonzeros: 1852
# 196
# tensor(176599704) tensor(181270513)
# elements in the bin: 0
# nonzeros: 1852
# 197
# tensor(181270513) tensor(183595983)
# elements in the bin: 0
# nonzeros: 1852
# 198
# tensor(183595983) tensor(180434300)
# elements in the bin: 3161683
# nonzeros: 1852
# 199
# tensor(180434300) tensor(182175575)
# elements in the bin: 0
# nonzeros: 1936
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:39: RuntimeWarning: divide by zero encountered in long_scalars
#   mean_count = counts_sel.sum() / n_lambdas
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: divide by zero encountered in long_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
# /home/tommaso/Dropbox/paper_NGS/binning_real_data_q/../utilities.py:40: RuntimeWarning: invalid value encountered in double_scalars
#   var_count = (counts_sel**2).sum() / n_lambdas - mean_count**2
