# %%
import numpy as np
import pandas as pd
import torch

import sys
sys.path.append('../')
from utilities import binning_equal_q

# %%
def infer_fields(data, counts):
    
    fields = np.zeros([7,20])
    for pos in range(7):
        for color in range(20):
            fields[pos,color] = (counts*((data[:,pos] == color).astype('int'))).sum() 

    print(counts.sum(), fields.sum(1))

    fields = fields[:,:] / fields[:,0][:,np.newaxis]
    return torch.tensor(np.log(fields))

def sorted_log10p_vector_from_fields(fields):
    
    lengths = [torch.arange(20, dtype=torch.int8) for i in range(7)]
    all_seq = torch.cartesian_prod(*lengths)
    
    all_seq = all_seq.long()
    
    # generate p_vector
    p_vector = torch.zeros(20**7,dtype=torch.float32)

    for i in range(7):
        p_vector += fields[i,all_seq[:,i]]
        print(i)
    
    p_vector = torch.exp(p_vector)
    
    Z = torch.exp(fields).sum(1).prod()
    
    p_vector /= Z
    print(p_vector.sum())
    
    return torch.log(p_vector).sort()[0] / np.log(10)

def log10q_vector_func(data, fields):
    
    # generate q_vector
    q_vector = torch.zeros(len(data))

    for i in range(7):
        q_vector += fields[i,data[:,i]]
        print(i)

    q_vector = torch.exp(q_vector)

    Z = torch.exp(fields).sum(1).prod()

    q_vector /= Z

    print(q_vector.sum())
    return np.log10(q_vector.numpy())

# %%
t = 4

# %%
data = pd.read_csv('../data/Byrne.csv',index_col=0).query('T0 > 0')
data = data.sort_values('T0', ascending=False)
data = data.iloc[1:,:]

np.random.seed(0)
data['sample'] = np.random.binomial(data['T0'], p=np.array([1/t]))
data = data.query('sample > 0')

counts = data['sample'].to_numpy()
data = data.iloc[:,:7].to_numpy()

# %%
fields = infer_fields(data, counts)
# Out:
# 3048615 [3048615. 3048615. 3048615. 3048615. 3048615. 3048615. 3048615.]

# %%
sorted_log10p_vector = sorted_log10p_vector_from_fields(fields)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# tensor(1.)

# %%
log10q_vector = log10q_vector_func(data, fields)
argsort = np.argsort(log10q_vector)
sorted_log10q_vector = log10q_vector[argsort][::-1]
counts = counts[argsort][::-1]
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# tensor(0.0071)

# %%
bins=80
df_bins = binning_equal_q(sorted_log10p_vector, sorted_log10q_vector, counts, bins=bins, writefolder=False)#'results_ByrneT0_IM', step=10)
df_bins.to_csv('df_bins_Byrne_IM_%dt.csv'%t)
# Out:
# 0
# tensor(1279999998) tensor(1279686273)
# elements in the bin: 313725
# nonzeros: 20111
# 1
# tensor(1279686273) tensor(1279208143)
# elements in the bin: 478130
# nonzeros: 20111
# 2
# tensor(1279208143) tensor(1278620499)
# elements in the bin: 587644
# nonzeros: 20111
# 3
# tensor(1278620499) tensor(1277925274)
# elements in the bin: 695225
# nonzeros: 20111
# 4
# tensor(1277925274) tensor(1277140525)
# elements in the bin: 784749
# nonzeros: 20111
# 5
# tensor(1277140525) tensor(1276252204)
# elements in the bin: 888321
# nonzeros: 20111
# 6
# tensor(1276252204) tensor(1275283519)
# elements in the bin: 968685
# nonzeros: 20111
# 7
# tensor(1275283519) tensor(1274214137)
# elements in the bin: 1069382
# nonzeros: 20111
# 8
# tensor(1274214137) tensor(1273071573)
# elements in the bin: 1142564
# nonzeros: 20111
# 9
# tensor(1273071573) tensor(1271826360)
# elements in the bin: 1245213
# nonzeros: 20111
# 10
# tensor(1271826360) tensor(1270512327)
# elements in the bin: 1314033
# nonzeros: 20111
# 11
# tensor(1270512327) tensor(1269090941)
# elements in the bin: 1421386
# nonzeros: 20111
# 12
# tensor(1269090941) tensor(1267568822)
# elements in the bin: 1522119
# nonzeros: 20111
# 13
# tensor(1267568822) tensor(1265942058)
# elements in the bin: 1626764
# nonzeros: 20111
# 14
# tensor(1265942058) tensor(1264254307)
# elements in the bin: 1687751
# nonzeros: 20111
# 15
# tensor(1264254307) tensor(1262453869)
# elements in the bin: 1800438
# nonzeros: 20111
# 16
# tensor(1262453869) tensor(1260562255)
# elements in the bin: 1891614
# nonzeros: 20111
# 17
# tensor(1260562255) tensor(1258550615)
# elements in the bin: 2011640
# nonzeros: 20111
# 18
# tensor(1258550615) tensor(1256396527)
# elements in the bin: 2154088
# nonzeros: 20111
# 19
# tensor(1256396527) tensor(1254182233)
# elements in the bin: 2214294
# nonzeros: 20111
# 20
# tensor(1254182233) tensor(1251817261)
# elements in the bin: 2364972
# nonzeros: 20111
# 21
# tensor(1251817261) tensor(1249349326)
# elements in the bin: 2467935
# nonzeros: 20111
# 22
# tensor(1249349326) tensor(1246791871)
# elements in the bin: 2557455
# nonzeros: 20111
# 23
# tensor(1246791871) tensor(1244107528)
# elements in the bin: 2684343
# nonzeros: 20111
# 24
# tensor(1244107528) tensor(1241241085)
# elements in the bin: 2866443
# nonzeros: 20111
# 25
# tensor(1241241085) tensor(1238274200)
# elements in the bin: 2966885
# nonzeros: 20111
# 26
# tensor(1238274200) tensor(1235156950)
# elements in the bin: 3117250
# nonzeros: 20111
# 27
# tensor(1235156950) tensor(1231882578)
# elements in the bin: 3274372
# nonzeros: 20111
# 28
# tensor(1231882578) tensor(1228490114)
# elements in the bin: 3392464
# nonzeros: 20111
# 29
# tensor(1228490114) tensor(1224908656)
# elements in the bin: 3581458
# nonzeros: 20111
# 30
# tensor(1224908656) tensor(1221146347)
# elements in the bin: 3762309
# nonzeros: 20111
# 31
# tensor(1221146347) tensor(1217263807)
# elements in the bin: 3882540
# nonzeros: 20111
# 32
# tensor(1217263807) tensor(1213223408)
# elements in the bin: 4040399
# nonzeros: 20111
# 33
# tensor(1213223408) tensor(1208955705)
# elements in the bin: 4267703
# nonzeros: 20111
# 34
# tensor(1208955705) tensor(1204539397)
# elements in the bin: 4416308
# nonzeros: 20111
# 35
# tensor(1204539397) tensor(1199953311)
# elements in the bin: 4586086
# nonzeros: 20111
# 36
# tensor(1199953311) tensor(1195156022)
# elements in the bin: 4797289
# nonzeros: 20111
# 37
# tensor(1195156022) tensor(1190085856)
# elements in the bin: 5070166
# nonzeros: 20111
# 38
# tensor(1190085856) tensor(1184724826)
# elements in the bin: 5361030
# nonzeros: 20111
# 39
# tensor(1184724826) tensor(1179146520)
# elements in the bin: 5578306
# nonzeros: 20111
# 40
# tensor(1179146520) tensor(1173369528)
# elements in the bin: 5776992
# nonzeros: 20111
# 41
# tensor(1173369528) tensor(1167258909)
# elements in the bin: 6110619
# nonzeros: 20111
# 42
# tensor(1167258909) tensor(1160897421)
# elements in the bin: 6361488
# nonzeros: 20111
# 43
# tensor(1160897421) tensor(1154280650)
# elements in the bin: 6616771
# nonzeros: 20111
# 44
# tensor(1154280650) tensor(1147227095)
# elements in the bin: 7053555
# nonzeros: 20111
# 45
# tensor(1147227095) tensor(1139985900)
# elements in the bin: 7241195
# nonzeros: 20111
# 46
# tensor(1139985900) tensor(1132324322)
# elements in the bin: 7661578
# nonzeros: 20111
# 47
# tensor(1132324322) tensor(1124341941)
# elements in the bin: 7982381
# nonzeros: 20111
# 48
# tensor(1124341941) tensor(1115959328)
# elements in the bin: 8382613
# nonzeros: 20111
# 49
# tensor(1115959328) tensor(1107003153)
# elements in the bin: 8956175
# nonzeros: 20111
# 50
# tensor(1107003153) tensor(1097771459)
# elements in the bin: 9231694
# nonzeros: 20111
# 51
# tensor(1097771459) tensor(1088093663)
# elements in the bin: 9677796
# nonzeros: 20111
# 52
# tensor(1088093663) tensor(1077858249)
# elements in the bin: 10235414
# nonzeros: 20111
# 53
# tensor(1077858249) tensor(1067032939)
# elements in the bin: 10825310
# nonzeros: 20111
# 54
# tensor(1067032939) tensor(1055629497)
# elements in the bin: 11403442
# nonzeros: 20111
# 55
# tensor(1055629497) tensor(1043728893)
# elements in the bin: 11900604
# nonzeros: 20111
# 56
# tensor(1043728893) tensor(1031078449)
# elements in the bin: 12650444
# nonzeros: 20111
# 57
# tensor(1031078449) tensor(1017544868)
# elements in the bin: 13533581
# nonzeros: 20111
# 58
# tensor(1017544868) tensor(1003387059)
# elements in the bin: 14157809
# nonzeros: 20111
# 59
# tensor(1003387059) tensor(988204358)
# elements in the bin: 15182701
# nonzeros: 20111
# 60
# tensor(988204358) tensor(971989749)
# elements in the bin: 16214609
# nonzeros: 20111
# 61
# tensor(971989749) tensor(955009939)
# elements in the bin: 16979810
# nonzeros: 20111
# 62
# tensor(955009939) tensor(936986950)
# elements in the bin: 18022989
# nonzeros: 20111
# 63
# tensor(936986950) tensor(917545661)
# elements in the bin: 19441289
# nonzeros: 20111
# 64
# tensor(917545661) tensor(896751135)
# elements in the bin: 20794526
# nonzeros: 20111
# 65
# tensor(896751135) tensor(874047103)
# elements in the bin: 22704032
# nonzeros: 20111
# 66
# tensor(874047103) tensor(850183350)
# elements in the bin: 23863753
# nonzeros: 20111
# 67
# tensor(850183350) tensor(823818570)
# elements in the bin: 26364780
# nonzeros: 20111
# 68
# tensor(823818570) tensor(795311379)
# elements in the bin: 28507191
# nonzeros: 20111
# 69
# tensor(795311379) tensor(764036384)
# elements in the bin: 31274995
# nonzeros: 20111
# 70
# tensor(764036384) tensor(729938252)
# elements in the bin: 34098132
# nonzeros: 20111
# 71
# tensor(729938252) tensor(692768003)
# elements in the bin: 37170249
# nonzeros: 20111
# 72
# tensor(692768003) tensor(651391187)
# elements in the bin: 41376816
# nonzeros: 20111
# 73
# tensor(651391187) tensor(604777434)
# elements in the bin: 46613753
# nonzeros: 20111
# 74
# tensor(604777434) tensor(551591641)
# elements in the bin: 53185793
# nonzeros: 20111
# 75
# tensor(551591641) tensor(490357608)
# elements in the bin: 61234033
# nonzeros: 20111
# 76
# tensor(490357608) tensor(418574719)
# elements in the bin: 71782889
# nonzeros: 20111
# 77
# tensor(418574719) tensor(330515769)
# elements in the bin: 88058950
# nonzeros: 20111
# 78
# tensor(330515769) tensor(215720430)
# elements in the bin: 114795339
# nonzeros: 20111
# 79
# tensor(215720430) tensor(145225)
# elements in the bin: 215575205
# nonzeros: 20125
