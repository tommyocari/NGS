# %%
import numpy as np
import pandas as pd

# %%
datasets = ['HBreastCancer','HLungCancer','HPBMC2','PBMCs','MBrain','MBrainCoronal']
#datasets = ['HBreastCancer','HPBMC2','MBrain','MBrainCoronal']
df = pd.DataFrame(index = datasets, columns = ['mean','variance','F','R','N_0','sat_frac','uniques'])
for dataset in datasets:
    data = pd.read_csv('/home/tommaso/new_phd/scRNAseq/data/'+dataset+'/UR_counts.csv', names=['seq','count'])
    uniques = len(data.query('count > 0'))
    mean = data['count'].sum() / (4.**16)
    variance = (((data['count'] - mean)**2).sum() + (4**16 - len(data))*(mean**2))/(4.**16)
    F = variance / mean
    R = data['count'].sum()
    N_0 = R / (F-1)
    sat_frac = np.sqrt((F-1)/F)
    df.loc[dataset] = [mean, variance, F, R, N_0, sat_frac,uniques]
    print(dataset)
# Out:
# HBreastCancer
# HLungCancer
# HPBMC2
# PBMCs
# MBrain
# MBrainCoronal

# %%
F = np.loadtxt('../binning_real_data_q/F_Dalkara.csv')[0]
data = pd.read_csv('../data/Dalkara.csv',index_col=0)
R = data['T0'].sum()
uniques = len(data.query('T0 > 0'))
N_0 = R / (F-1)
sat_frac = np.sqrt((F-1)/F)
df.loc['DalkaraT0'] = [np.nan, np.nan, F, R, N_0, sat_frac,uniques]

# %%
F = np.loadtxt('../binning_real_data_q/F_Byrne.csv')[0]
data = pd.read_csv('../data/Byrne.csv',index_col=0).sort_values('T0', ascending=False).iloc[1:,:]
R = data['T0'].sum()
uniques = len(data.query('T0 > 0'))
N_0 = R / (F-1)
sat_frac = np.sqrt((F-1)/F)
df.loc['ByrneT0'] = [np.nan, np.nan, F, R, N_0, sat_frac, uniques]

# %%
F = np.loadtxt('../binning_real_data_q/F_Twist.csv')[0]
data = pd.read_csv('/home/tommaso/new_phd/data/Twist_T0.csv',index_col=0)
R = data['T0'].sum()
uniques = len(data)
N_0 = R / (F-1)
sat_frac = np.sqrt((F-1)/F)
df.loc['TwistT0'] = [np.nan, np.nan, F, R, N_0, sat_frac, uniques]

# %%
df.sort_values('sat_frac').to_csv('df.csv')

# %%
df.sort_values('sat_frac')
# Out:
#                    mean  variance          F            R              N_0  \
# TwistT0             NaN       NaN   3.936907  240537294.0  81901570.155149
# DalkaraT0           NaN       NaN   5.550332   13653491.0   3000548.105826
# ByrneT0             NaN       NaN   8.922473   12195473.0   1539351.719148
# HBreastCancer  0.017653  0.187518  10.622273     75820168    7879652.62138
# HLungCancer    0.032133  0.547026  17.023755    138010491   8612868.293717
# MBrain         0.040356  0.902225   22.35684    173326275   8115726.625688
# MBrainCoronal  0.072693  3.490021  48.010542    312213184   6641344.047791
# PBMCs          0.017909   1.12794    62.9831     76916896   1240933.348372
# HPBMC2         0.042452  3.221978  75.896609    182330818   2434433.559131
#
#                sat_frac     uniques
# TwistT0        0.863709  98468090.0
# DalkaraT0      0.905445   1252032.0
# ByrneT0        0.942297   3071451.0
# HBreastCancer  0.951766    14512602
# HLungCancer    0.970185    15587403
# MBrain          0.97738    16020053
# MBrainCoronal  0.989531    16429852
# PBMCs           0.99203    10546968
# HPBMC2          0.99339    14974774
