# %%
import numpy as np
import pandas as pd
import torch

import sys
sys.path.append('../')
from utilities import binning_equal_lambdas

# %%
def infer_fields(data, counts):
    
    fields = np.zeros([7,20])
    for pos in range(7):
        for color in range(20):
            fields[pos,color] = (counts*((data[:,pos] == color).astype('int'))).sum() 

    print(counts.sum(), fields.sum(1))

    fields = fields[:,:] / fields[:,0][:,np.newaxis]
    return torch.tensor(np.log(fields))

def sorted_log10p_vector_from_fields(fields):
    
    lengths = [torch.arange(20, dtype=torch.int8) for i in range(7)]
    all_seq = torch.cartesian_prod(*lengths)
    
    all_seq = all_seq.long()
    
    # generate p_vector
    p_vector = torch.zeros(20**7,dtype=torch.float32)

    for i in range(7):
        p_vector += fields[i,all_seq[:,i]]
        print(i)
    
    p_vector = torch.exp(p_vector)
    
    Z = torch.exp(fields).sum(1).prod()
    
    p_vector /= Z
    print(p_vector.sum())
    
    return torch.log(p_vector).sort()[0] / np.log(10)

def log10q_vector_func(data, fields):
    
    # generate q_vector
    q_vector = torch.zeros(len(data))

    for i in range(7):
        q_vector += fields[i,data[:,i]]
        print(i)

    q_vector = torch.exp(q_vector)

    Z = torch.exp(fields).sum(1).prod()

    q_vector /= Z

    print(q_vector.sum())
    return np.log10(q_vector.numpy())

# %%
data = pd.read_csv('../data/Byrne.csv',index_col=0).query('T0 > 0')
data = data.sort_values('T0', ascending=False)
data = data.iloc[1:,:]

counts = data['T0'].to_numpy()
data = data.iloc[:,:7].to_numpy()

# %%
fields = infer_fields(data, counts)
# Out:
# 12195473 [12195473. 12195473. 12195473. 12195473. 12195473. 12195473. 12195473.]

# %%
sorted_log10p_vector = sorted_log10p_vector_from_fields(fields)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# tensor(1.)

# %%
log10q_vector = log10q_vector_func(data, fields)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# tensor(0.0130)

# %%
bins=100000
df_bins = binning_equal_lambdas(torch.flip(sorted_log10p_vector,dims=(0,)), log10q_vector, counts, bins=bins, writefolder=False)#'results_ByrneT0_IM', step=10)
df_bins.to_csv('df_bins_Byrne_IM_%dbins.csv'%bins)
# Out:
# 0
# elements in the bin: 12800
# 1
# elements in the bin: 12800
# 2
# elements in the bin: 12800
# 3
# elements in the bin: 12800
# 4
# elements in the bin: 12800
# 5
# elements in the bin: 12800
# 6
# elements in the bin: 12800
# 7
# elements in the bin: 12800
# 8
# elements in the bin: 12800
# 9
# elements in the bin: 12800
# 10
# elements in the bin: 12800
# 11
# elements in the bin: 12800
# 12
# elements in the bin: 12800
# 13
# elements in the bin: 12800
# 14
# elements in the bin: 12800
# 15
# elements in the bin: 12800
# 16
# elements in the bin: 12800
# 17
# elements in the bin: 12800
# 18
# elements in the bin: 12800
# 19
# elements in the bin: 12800
# 20
# elements in the bin: 12800
# 21
# elements in the bin: 12800
# 22
# elements in the bin: 12800
# 23
# elements in the bin: 12800
# 24
# elements in the bin: 12800
# 25
# elements in the bin: 12800
# 26
# elements in the bin: 12800
# 27
# elements in the bin: 12800
# 28
# elements in the bin: 12800
# 29
# elements in the bin: 12800
# 30
# elements in the bin: 12800
# 31
# elements in the bin: 12800
# 32
# elements in the bin: 12800
# 33
# elements in the bin: 12800
# 34
# elements in the bin: 12800
# 35
# elements in the bin: 12800
# 36
# elements in the bin: 12800
# 37
# elements in the bin: 12800
# 38
# elements in the bin: 12800
# 39
# elements in the bin: 12800
# 40
# elements in the bin: 12800
# 41
# elements in the bin: 12800
# 42
# elements in the bin: 12800
# 43
# elements in the bin: 12800
# 44
# elements in the bin: 12800
# 45
# elements in the bin: 12800
# 46
# elements in the bin: 12800
# 47
# elements in the bin: 12800
# 48
# elements in the bin: 12800
# 49
# elements in the bin: 12800
# 50
# elements in the bin: 12800
# 51
# elements in the bin: 12800
# 52
# elements in the bin: 12800
# 53
# elements in the bin: 12800
# 54
# elements in the bin: 12800
# 55
# elements in the bin: 12800
# 56
# elements in the bin: 12800
# 57
# elements in the bin: 12800
# 58
# elements in the bin: 12800
# 59
# elements in the bin: 12800
# 60
# elements in the bin: 12800
# 61
# elements in the bin: 12800
# 62
# elements in the bin: 12800
# 63
# elements in the bin: 12800
# 64
# elements in the bin: 12800
# 65
# elements in the bin: 12800
# 66
# elements in the bin: 12800
# 67
# elements in the bin: 12800
# 68
# elements in the bin: 12800
# 69
# elements in the bin: 12800
# 70
# elements in the bin: 12800
# 71
# elements in the bin: 12800
# 72
# elements in the bin: 12800
# 73
# elements in the bin: 12800
# 74
# elements in the bin: 12800
# 75
# elements in the bin: 12800
# 76
# elements in the bin: 12800
# 77
# elements in the bin: 12800
# 78
# elements in the bin: 12800
# 79
# elements in the bin: 12800
# 80
# elements in the bin: 12800
# 81
# elements in the bin: 12800
# 82
# elements in the bin: 12800
# 83
# elements in the bin: 12800
# 84
# elements in the bin: 12800
# 85
# elements in the bin: 12800
# 86
# elements in the bin: 12800
# 87
# elements in the bin: 12800
# 88
# elements in the bin: 12800
# 89
# elements in the bin: 12800
# 90
# elements in the bin: 12800
# 91
# elements in the bin: 12800
# 92
# elements in the bin: 12800
# 93
# elements in the bin: 12800
# 94
# elements in the bin: 12800
# 95
# elements in the bin: 12800
# 96
# elements in the bin: 12800
# 97
# elements in the bin: 12800
# 98
# elements in the bin: 12800
# 99
# elements in the bin: 12800
# 100
# elements in the bin: 12800
# 101
# elements in the bin: 12800
# 102
# elements in the bin: 12800
# 103
# elements in the bin: 12800
# 104
# elements in the bin: 12800
# 105
# elements in the bin: 12800
# 106
# elements in the bin: 12800
# 107
# elements in the bin: 12800
# 108
# elements in the bin: 12800
# 109
# elements in the bin: 12800
# 110
# elements in the bin: 12800
# 111
# elements in the bin: 12800
# 112
# elements in the bin: 12800
# 113
# elements in the bin: 12800
# 114
# elements in the bin: 12800
# 115
# elements in the bin: 12800
# 116
# elements in the bin: 12800
# 117
# elements in the bin: 12800
# 118
# elements in the bin: 12800
# 119
# elements in the bin: 12800
# 120
# elements in the bin: 12800
# 121
# elements in the bin: 12800
# 122
# elements in the bin: 12800
# 123
# elements in the bin: 12800
# 124
# elements in the bin: 12800
# 125
# elements in the bin: 12800
# 126
# elements in the bin: 12800
# 127
# elements in the bin: 12800
# 128
# elements in the bin: 12800
# 129
# elements in the bin: 12800
# 130
# elements in the bin: 12800
# 131
# elements in the bin: 12800
# 132
# elements in the bin: 12800
# 133
# elements in the bin: 12800
# 134
# elements in the bin: 12800
# 135
# elements in the bin: 12800
# 136
# elements in the bin: 12800
# 137
# elements in the bin: 12800
# 138
# elements in the bin: 12800
# 139
# elements in the bin: 12800
# 140
# elements in the bin: 12800
# 141
# elements in the bin: 12800
# 142
# elements in the bin: 12800
# 143
# elements in the bin: 12800
# 144
# elements in the bin: 12800
# 145
# elements in the bin: 12800
# 146
# elements in the bin: 12800
# 147
# elements in the bin: 12800
# 148
# elements in the bin: 12800
# 149
# elements in the bin: 12800
# 150
# elements in the bin: 12800
# 151
# elements in the bin: 12800
# 152
# elements in the bin: 12800
# 153
# elements in the bin: 12800
# 154
# elements in the bin: 12800
# 155
# elements in the bin: 12800
# 156
# elements in the bin: 12800
# 157
# elements in the bin: 12800
# 158
# elements in the bin: 12800
# 159
# elements in the bin: 12800
# 160
# elements in the bin: 12800
# 161
# elements in the bin: 12800
# 162
# elements in the bin: 12800
# 163
# elements in the bin: 12800
# 164
# elements in the bin: 12800
# 165
# elements in the bin: 12800
# 166
# elements in the bin: 12800
# 167
# elements in the bin: 12800
# 168
# elements in the bin: 12800
# 169
# elements in the bin: 12800
# 170
# elements in the bin: 12800
# 171
# elements in the bin: 12800
# 172
# elements in the bin: 12800
# 173
# elements in the bin: 12800
# 174
# elements in the bin: 12800
# 175
# elements in the bin: 12800
# 176
# elements in the bin: 12800
# 177
# elements in the bin: 12800
# 178
# elements in the bin: 12800
# 179
# elements in the bin: 12800
# 180
# elements in the bin: 12800
# 181
# elements in the bin: 12800
# 182
# elements in the bin: 12800
# 183
# elements in the bin: 12800
# 184
# elements in the bin: 12800
# 185
# elements in the bin: 12800
# 186
# elements in the bin: 12800
# 187
# elements in the bin: 12800
# 188
# elements in the bin: 12800
# 189
# elements in the bin: 12800
# 190
# elements in the bin: 12800
# 191
# elements in the bin: 12800
# 192
# elements in the bin: 12800
# 193
# elements in the bin: 12800
# 194
# elements in the bin: 12800
# 195
# elements in the bin: 12800
# 196
# elements in the bin: 12800
# 197
# elements in the bin: 12800
# 198
# elements in the bin: 12800
# 199
# elements in the bin: 12800
# 200
# elements in the bin: 12800
# 201
# elements in the bin: 12800
# 202
# elements in the bin: 12800
# 203
# elements in the bin: 12800
# 204
# elements in the bin: 12800
# 205
# elements in the bin: 12800
# 206
# elements in the bin: 12800
# 207
# elements in the bin: 12800
# 208
# elements in the bin: 12800
# 209
# elements in the bin: 12800
# 210
# elements in the bin: 12800
# 211
# elements in the bin: 12800
# 212
# elements in the bin: 12800
# 213
# elements in the bin: 12800
# 214
# elements in the bin: 12800
# 215
# elements in the bin: 12800
# 216
# elements in the bin: 12800
# 217
# elements in the bin: 12800
# 218
# elements in the bin: 12800
# 219
# elements in the bin: 12800
# 220
# elements in the bin: 12800
# 221
# elements in the bin: 12800
# 222
# elements in the bin: 12800
# 223
# elements in the bin: 12800
# 224
# elements in the bin: 12800
# 225
# elements in the bin: 12800
# 226
# elements in the bin: 12800
# 227
# elements in the bin: 12800
# 228
# elements in the bin: 12800
# 229
# elements in the bin: 12800
# 230
# elements in the bin: 12800
# 231
# elements in the bin: 12800
# 232
# elements in the bin: 12800
# 233
# elements in the bin: 12800
# 234
# elements in the bin: 12800
# 235
# elements in the bin: 12800
# 236
# elements in the bin: 12800
# 237
# elements in the bin: 12800
# 238
# elements in the bin: 12800
# 239
# elements in the bin: 12800
# 240
# elements in the bin: 12800
# 241
# elements in the bin: 12800
# 242
# elements in the bin: 12800
# 243
# elements in the bin: 12800
# 244
# elements in the bin: 12800
# 245
# elements in the bin: 12800
# 246
# elements in the bin: 12800
# 247
# elements in the bin: 12800
# 248
# elements in the bin: 12800
# 249
# elements in the bin: 12800
# 250
# elements in the bin: 12800
# 251
# elements in the bin: 12800
# 252
# elements in the bin: 12800
# 253
# elements in the bin: 12800
# 254
# elements in the bin: 12800
# 255
# elements in the bin: 12800
# 256
# elements in the bin: 12800
# 257
# elements in the bin: 12800
# 258
# elements in the bin: 12800
# 259
# elements in the bin: 12800
# 260
# elements in the bin: 12800
# 261
# elements in the bin: 12800
# 262
# elements in the bin: 12800
# 263
# elements in the bin: 12800
# 264
# elements in the bin: 12800
# 265
# elements in the bin: 12800
# 266
# elements in the bin: 12800
# 267
# elements in the bin: 12800
# 268
# elements in the bin: 12800
# 269
# elements in the bin: 12800
# 270
# elements in the bin: 12800
# 271
# elements in the bin: 12800
# 272
# elements in the bin: 12800
# 273
# elements in the bin: 12800
# 274
# elements in the bin: 12800
# 275
# elements in the bin: 12800
# 276
# elements in the bin: 12800
# 277
# elements in the bin: 12800
# 278
# elements in the bin: 12800
# 279
# elements in the bin: 12800
# 280
# elements in the bin: 12800
# 281
# elements in the bin: 12800
# 282
# elements in the bin: 12800
# 283
# elements in the bin: 12800
# 284
# elements in the bin: 12800
# 285
# elements in the bin: 12800
# 286
# elements in the bin: 12800
# 287
# elements in the bin: 12800
# 288
# elements in the bin: 12800
# 289
# elements in the bin: 12800
# 290
# elements in the bin: 12800
# 291
# elements in the bin: 12800
# 292
# elements in the bin: 12800
# 293
# elements in the bin: 12800
# 294
# elements in the bin: 12800
# 295
# elements in the bin: 12800
# 296
# elements in the bin: 12800
# 297
# elements in the bin: 12800
# 298
# elements in the bin: 12800
# 299
# elements in the bin: 12800
# 300
# elements in the bin: 12800
# 301
# elements in the bin: 12800
# 302
# elements in the bin: 12800
# 303
# elements in the bin: 12800
# 304
# elements in the bin: 12800
# 305
# elements in the bin: 12800
# 306
# elements in the bin: 12800
# 307
# elements in the bin: 12800
# 308
# elements in the bin: 12800
# 309
# elements in the bin: 12800
# 310
# elements in the bin: 12800
# 311
# elements in the bin: 12800
# 312
# elements in the bin: 12800
# 313
# elements in the bin: 12800
# 314
# elements in the bin: 12800
# 315
# elements in the bin: 12800
# 316
# elements in the bin: 12800
# 317
# elements in the bin: 12800
# 318
# elements in the bin: 12800
# 319
# elements in the bin: 12800
# 320
# elements in the bin: 12800
# 321
# elements in the bin: 12800
# 322
# elements in the bin: 12800
# 323
# elements in the bin: 12800
# 324
# elements in the bin: 12800
# 325
# elements in the bin: 12800
# 326
# elements in the bin: 12800
# 327
# elements in the bin: 12800
# 328
# elements in the bin: 12800
# 329
# elements in the bin: 12800
# 330
# elements in the bin: 12800
# 331
# elements in the bin: 12800
# 332
# elements in the bin: 12800
# 333
# elements in the bin: 12800
# 334
# elements in the bin: 12800
# 335
# elements in the bin: 12800
# 336
# elements in the bin: 12800
# 337
# elements in the bin: 12800
# 338
# elements in the bin: 12800
# 339
# elements in the bin: 12800
# 340
# elements in the bin: 12800
# 341
# elements in the bin: 12800
# 342
# elements in the bin: 12800
# 343
# elements in the bin: 12800
# 344
# elements in the bin: 12800
# 345
# elements in the bin: 12800
# 346
# elements in the bin: 12800
# 347
# elements in the bin: 12800
# 348
# elements in the bin: 12800
# 349
# elements in the bin: 12800
# 350
# elements in the bin: 12800
# 351
# elements in the bin: 12800
# 352
# elements in the bin: 12800
# 353
# elements in the bin: 12800
# 354
# elements in the bin: 12800
# 355
# elements in the bin: 12800
# 356
# elements in the bin: 12800
# 357
# elements in the bin: 12800
# 358
# elements in the bin: 12800
# 359
# elements in the bin: 12800
# 360
# elements in the bin: 12800
# 361
# elements in the bin: 12800
# 362
# elements in the bin: 12800
# 363
# elements in the bin: 12800
# 364
# elements in the bin: 12800
# 365
# elements in the bin: 12800
# 366
# elements in the bin: 12800
# 367
# elements in the bin: 12800
# 368
# elements in the bin: 12800
# 369
# elements in the bin: 12800
# 370
# elements in the bin: 12800
# 371
# elements in the bin: 12800
# 372
# elements in the bin: 12800
# 373
# elements in the bin: 12800
# 374
# elements in the bin: 12800
# 375
# elements in the bin: 12800
# 376
# elements in the bin: 12800
# 377
# elements in the bin: 12800
# 378
# elements in the bin: 12800
# 379
# elements in the bin: 12800
# 380
# elements in the bin: 12800
# 381
# elements in the bin: 12800
# 382
# elements in the bin: 12800
# 383
# elements in the bin: 12800
# 384
# elements in the bin: 12800
# 385
# elements in the bin: 12800
# 386
# elements in the bin: 12800
# 387
# elements in the bin: 12800
# 388
# elements in the bin: 12800
# 389
# elements in the bin: 12800
# 390
# elements in the bin: 12800
# 391
# elements in the bin: 12800
# 392
# elements in the bin: 12800
# 393
# elements in the bin: 12800
# 394
# elements in the bin: 12800
# 395
# elements in the bin: 12800
# 396
# elements in the bin: 12800
# 397
# elements in the bin: 12800
# 398
# elements in the bin: 12800
# 399
# elements in the bin: 12800
# 400
# elements in the bin: 12800
# 401
# elements in the bin: 12800
# 402
# elements in the bin: 12800
# 403
# elements in the bin: 12800
# 404
# elements in the bin: 12800
# 405
# elements in the bin: 12800
# 406
# elements in the bin: 12800
# 407
# elements in the bin: 12800
# 408
# elements in the bin: 12800
# 409
# elements in the bin: 12800
# 410
# elements in the bin: 12800
# 411
# elements in the bin: 12800
# 412
# elements in the bin: 12800
# 413
# elements in the bin: 12800
# 414
# elements in the bin: 12800
# 415
# elements in the bin: 12800
# 416
# elements in the bin: 12800
# 417
# elements in the bin: 12800
# 418
# elements in the bin: 12800
# 419
# elements in the bin: 12800
# 420
# elements in the bin: 12800
# 421
# elements in the bin: 12800
# 422
# elements in the bin: 12800
# 423
# elements in the bin: 12800
# 424
# elements in the bin: 12800
# 425
# elements in the bin: 12800
# 426
# elements in the bin: 12800
# 427
# elements in the bin: 12800
# 428
# elements in the bin: 12800
# 429
# elements in the bin: 12800
# 430
# elements in the bin: 12800
# 431
# elements in the bin: 12800
# 432
# elements in the bin: 12800
# 433
# elements in the bin: 12800
# 434
# elements in the bin: 12800
# 435
# elements in the bin: 12800
# 436
# elements in the bin: 12800
# 437
# elements in the bin: 12800
# 438
# elements in the bin: 12800
# 439
# elements in the bin: 12800
# 440
# elements in the bin: 12800
# 441
# elements in the bin: 12800
# 442
# elements in the bin: 12800
# 443
# elements in the bin: 12800
# 444
# elements in the bin: 12800
# 445
# elements in the bin: 12800
# 446
# elements in the bin: 12800
# 447
# elements in the bin: 12800
# 448
# elements in the bin: 12800
# 449
# elements in the bin: 12800
# 450
# elements in the bin: 12800
# 451
# elements in the bin: 12800
# 452
# elements in the bin: 12800
# 453
# elements in the bin: 12800
# 454
# elements in the bin: 12800
# 455
# elements in the bin: 12800
# 456
# elements in the bin: 12800
# 457
# elements in the bin: 12800
# 458
# elements in the bin: 12800
# 459
# elements in the bin: 12800
# 460
# elements in the bin: 12800
# 461
# elements in the bin: 12800
# 462
# elements in the bin: 12800
# 463
# elements in the bin: 12800
# 464
# elements in the bin: 12800
# 465
# elements in the bin: 12800
# 466
# elements in the bin: 12800
# 467
# elements in the bin: 12800
# 468
# elements in the bin: 12800
# 469
# elements in the bin: 12800
# 470
# elements in the bin: 12800
# 471
# elements in the bin: 12800
# 472
# elements in the bin: 12800
# 473
# elements in the bin: 12800
# 474
# elements in the bin: 12800
# 475
# elements in the bin: 12800
# 476
# elements in the bin: 12800
# 477
# elements in the bin: 12800
# 478
# elements in the bin: 12800
# 479
# elements in the bin: 12800
# 480
# elements in the bin: 12800
# 481
# elements in the bin: 12800
# 482
# elements in the bin: 12800
# 483
# elements in the bin: 12800
# 484
# elements in the bin: 12800
# 485
# elements in the bin: 12800
# 486
# elements in the bin: 12800
# 487
# elements in the bin: 12800
# 488
# elements in the bin: 12800
# 489
# elements in the bin: 12800
# 490
# elements in the bin: 12800
# 491
# elements in the bin: 12800
# 492
# elements in the bin: 12800
# 493
# elements in the bin: 12800
# 494
# elements in the bin: 12800
# 495
# elements in the bin: 12800
# 496
# elements in the bin: 12800
# 497
# elements in the bin: 12800
# 498
# elements in the bin: 12800
# 499
# elements in the bin: 12800
# 500
# elements in the bin: 12800
# 501
# elements in the bin: 12800
# 502
# elements in the bin: 12800
# 503
# elements in the bin: 12800
# 504
# elements in the bin: 12800
# 505
# elements in the bin: 12800
# 506
# elements in the bin: 12800
# 507
# elements in the bin: 12800
# 508
# elements in the bin: 12800
# 509
# elements in the bin: 12800
# 510
# elements in the bin: 12800
# 511
# elements in the bin: 12800
# 512
# elements in the bin: 12800
# 513
# elements in the bin: 12800
# 514
# elements in the bin: 12800
# 515
# elements in the bin: 12800
# 516
# elements in the bin: 12800
# 517
# elements in the bin: 12800
# 518
# elements in the bin: 12800
# 519
# elements in the bin: 12800
# 520
# elements in the bin: 12800
# 521
# elements in the bin: 12800
# 522
# elements in the bin: 12800
# 523
# elements in the bin: 12800
# 524
# elements in the bin: 12800
# 525
# elements in the bin: 12800
# 526
# elements in the bin: 12800
# 527
# elements in the bin: 12800
# 528
# elements in the bin: 12800
# 529
# elements in the bin: 12800
# 530
# elements in the bin: 12800
# 531
# elements in the bin: 12800
# 532
# elements in the bin: 12800
# 533
# elements in the bin: 12800
# 534
# elements in the bin: 12800
# 535
# elements in the bin: 12800
# 536
# elements in the bin: 12800
# 537
# elements in the bin: 12800
# 538
# elements in the bin: 12800
# 539
# elements in the bin: 12800
# 540
# elements in the bin: 12800
# 541
# elements in the bin: 12800
# 542
# elements in the bin: 12800
# 543
# elements in the bin: 12800
# 544
# elements in the bin: 12800
# 545
# elements in the bin: 12800
# 546
# elements in the bin: 12800
# 547
# elements in the bin: 12800
# 548
# elements in the bin: 12800
# 549
# elements in the bin: 12800
# 550
# elements in the bin: 12800
# 551
# elements in the bin: 12800
# 552
# elements in the bin: 12800
# 553
# elements in the bin: 12800
# 554
# elements in the bin: 12800
# 555
# elements in the bin: 12800
# 556
# elements in the bin: 12800
# 557
# elements in the bin: 12800
# 558
# elements in the bin: 12800
# 559
# elements in the bin: 12800
# 560
# elements in the bin: 12800
# 561
# elements in the bin: 12800
# 562
# elements in the bin: 12800
# 563
# elements in the bin: 12800
# 564
# elements in the bin: 12800
# 565
# elements in the bin: 12800
# 566
# elements in the bin: 12800
# 567
# elements in the bin: 12800
# 568
# elements in the bin: 12800
# 569
# elements in the bin: 12800
# 570
# elements in the bin: 12800
# 571
# elements in the bin: 12800
# 572
# elements in the bin: 12800
# 573
# elements in the bin: 12800
# 574
# elements in the bin: 12800
# 575
# elements in the bin: 12800
# 576
# elements in the bin: 12800
# 577
# elements in the bin: 12800
# 578
# elements in the bin: 12800
# 579
# elements in the bin: 12800
# 580
# elements in the bin: 12800
# 581
# elements in the bin: 12800
# 582
# elements in the bin: 12800
# 583
# elements in the bin: 12800
# 584
# elements in the bin: 12800
# 585
# elements in the bin: 12800
# 586
# elements in the bin: 12800
# 587
# elements in the bin: 12800
# 588
# elements in the bin: 12800
# 589
# elements in the bin: 12800
# 590
# elements in the bin: 12800
# 591
# elements in the bin: 12800
# 592
# elements in the bin: 12800
# 593
# elements in the bin: 12800
# 594
# elements in the bin: 12800
# 595
# elements in the bin: 12800
# 596
# elements in the bin: 12800
# 597
# elements in the bin: 12800
# 598
# elements in the bin: 12800
# 599
# elements in the bin: 12800
# 600
# elements in the bin: 12800
# 601
# elements in the bin: 12800
# 602
# elements in the bin: 12800
# 603
# elements in the bin: 12800
# 604
# elements in the bin: 12800
# 605
# elements in the bin: 12800
# 606
# elements in the bin: 12800
# 607
# elements in the bin: 12800
# 608
# elements in the bin: 12800
# 609
# elements in the bin: 12800
# 610
# elements in the bin: 12800
# 611
# elements in the bin: 12800
# 612
# elements in the bin: 12800
# 613
# elements in the bin: 12800
# 614
# elements in the bin: 12800
# 615
# elements in the bin: 12800
# 616
# elements in the bin: 12800
# 617
# elements in the bin: 12800
# 618
# elements in the bin: 12800
# 619
# elements in the bin: 12800
# 620
# elements in the bin: 12800
# 621
# elements in the bin: 12800
# 622
# elements in the bin: 12800
# 623
# elements in the bin: 12800
# 624
# elements in the bin: 12800
# 625
# elements in the bin: 12800
# 626
# elements in the bin: 12800
# 627
# elements in the bin: 12800
# 628
# elements in the bin: 12800
# 629
# elements in the bin: 12800
# 630
# elements in the bin: 12800
# 631
# elements in the bin: 12800
# 632
# elements in the bin: 12800
# 633
# elements in the bin: 12800
# 634
# elements in the bin: 12800
# 635
# elements in the bin: 12800
# 636
# elements in the bin: 12800
# 637
# elements in the bin: 12800
# 638
# elements in the bin: 12800
# 639
# elements in the bin: 12800
# 640
# elements in the bin: 12800
# 641
# elements in the bin: 12800
# 642
# elements in the bin: 12800
# 643
# elements in the bin: 12800
# 644
# elements in the bin: 12800
# 645
# elements in the bin: 12800
# 646
# elements in the bin: 12800
# 647
# elements in the bin: 12800
# 648
# elements in the bin: 12800
# 649
# elements in the bin: 12800
# 650
# elements in the bin: 12800
# 651
# elements in the bin: 12800
# 652
# elements in the bin: 12800
# 653
# elements in the bin: 12800
# 654
# elements in the bin: 12800
# 655
# elements in the bin: 12800
# 656
# elements in the bin: 12800
# 657
# elements in the bin: 12800
# 658
# elements in the bin: 12800
# 659
# elements in the bin: 12800
# 660
# elements in the bin: 12800
# 661
# elements in the bin: 12800
# 662
# elements in the bin: 12800
# 663
# elements in the bin: 12800
# 664
# elements in the bin: 12800
# 665
# elements in the bin: 12800
# 666
# elements in the bin: 12800
# 667
# elements in the bin: 12800
# 668
# elements in the bin: 12800
# 669
# elements in the bin: 12800
# 670
# elements in the bin: 12800
# 671
# elements in the bin: 12800
# 672
# elements in the bin: 12800
# 673
# elements in the bin: 12800
# 674
# elements in the bin: 12800
# 675
# elements in the bin: 12800
# 676
# elements in the bin: 12800
# 677
# elements in the bin: 12800
# 678
# elements in the bin: 12800
# 679
# elements in the bin: 12800
# 680
# elements in the bin: 12800
# 681
# elements in the bin: 12800
# 682
# elements in the bin: 12800
# 683
# elements in the bin: 12800
# 684
# elements in the bin: 12800
# 685
# elements in the bin: 12800
# 686
# elements in the bin: 12800
# 687
# elements in the bin: 12800
# 688
# elements in the bin: 12800
# 689
# elements in the bin: 12800
# 690
# elements in the bin: 12800
# 691
# elements in the bin: 12800
# 692
# elements in the bin: 12800
# 693
# elements in the bin: 12800
# 694
# elements in the bin: 12800
# 695
# elements in the bin: 12800
# 696
# elements in the bin: 12800
# 697
# elements in the bin: 12800
# 698
# elements in the bin: 12800
# 699
# elements in the bin: 12800
# 700
# elements in the bin: 12800
# 701
# elements in the bin: 12800
# 702
# elements in the bin: 12800
# 703
# elements in the bin: 12800
# 704
# elements in the bin: 12800
# 705
# elements in the bin: 12800
# 706
# elements in the bin: 12800
# 707
# elements in the bin: 12800
# 708
# elements in the bin: 12800
# 709
# elements in the bin: 12800
# 710
# elements in the bin: 12800
# 711
# elements in the bin: 12800
# 712
# elements in the bin: 12800
# 713
# elements in the bin: 12800
# 714
# elements in the bin: 12800
# 715
# elements in the bin: 12800
# 716
# elements in the bin: 12800
# 717
# elements in the bin: 12800
# 718
# elements in the bin: 12800
# 719
# elements in the bin: 12800
# 720
# elements in the bin: 12800
# 721
# elements in the bin: 12800
# 722
# elements in the bin: 12800
# 723
# elements in the bin: 12800
# 724
# elements in the bin: 12800
# 725
# elements in the bin: 12800
# 726
# elements in the bin: 12800
# 727
# elements in the bin: 12800
# 728
# elements in the bin: 12800
# 729
# elements in the bin: 12800
# 730
# elements in the bin: 12800
# 731
# elements in the bin: 12800
# 732
# elements in the bin: 12800
# 733
# elements in the bin: 12800
# 734
# elements in the bin: 12800
# 735
# elements in the bin: 12800
# 736
# elements in the bin: 12800
# 737
# elements in the bin: 12800
# 738
# elements in the bin: 12800
# 739
# elements in the bin: 12800
# 740
# elements in the bin: 12800
# 741
# elements in the bin: 12800
# 742
# elements in the bin: 12800
# 743
# elements in the bin: 12800
# 744
# elements in the bin: 12800
# 745
# elements in the bin: 12800
# 746
# elements in the bin: 12800
# 747
# elements in the bin: 12800
# 748
# elements in the bin: 12800
# 749
# elements in the bin: 12800
# 750
# elements in the bin: 12800
# 751
# elements in the bin: 12800
# 752
# elements in the bin: 12800
# 753
# elements in the bin: 12800
# 754
# elements in the bin: 12800
# 755
# elements in the bin: 12800
# 756
# elements in the bin: 12800
# 757
# elements in the bin: 12800
# 758
# elements in the bin: 12800
# 759
# elements in the bin: 12800
# 760
# elements in the bin: 12800
# 761
# elements in the bin: 12800
# 762
# elements in the bin: 12800
# 763
# elements in the bin: 12800
# 764
# elements in the bin: 12800
# 765
# elements in the bin: 12800
# 766
# elements in the bin: 12800
# 767
# elements in the bin: 12800
# 768
# elements in the bin: 12800
# 769
# elements in the bin: 12800
# 770
# elements in the bin: 12800
# 771
# elements in the bin: 12800
# 772
# elements in the bin: 12800
# 773
# elements in the bin: 12800
# 774
# elements in the bin: 12800
# 775
# elements in the bin: 12800
# 776
# elements in the bin: 12800
# 777
# elements in the bin: 12800
# 778
# elements in the bin: 12800
# 779
# elements in the bin: 12800
# 780
# elements in the bin: 12800
# 781
# elements in the bin: 12800
# 782
# elements in the bin: 12800
# 783
# elements in the bin: 12800
# 784
# elements in the bin: 12800
# 785
# elements in the bin: 12800
# 786
# elements in the bin: 12800
# 787
# elements in the bin: 12800
# 788
# elements in the bin: 12800
# 789
# elements in the bin: 12800
# 790
# elements in the bin: 12800
# 791
# elements in the bin: 12800
# 792
# elements in the bin: 12800
# 793
# elements in the bin: 12800
# 794
# elements in the bin: 12800
# 795
# elements in the bin: 12800
# 796
# elements in the bin: 12800
# 797
# elements in the bin: 12800
# 798
# elements in the bin: 12800
# 799
# elements in the bin: 12800
# 800
# elements in the bin: 12800
# 801
# elements in the bin: 12800
# 802
# elements in the bin: 12800
# 803
# elements in the bin: 12800
# 804
# elements in the bin: 12800
# 805
# elements in the bin: 12800
# 806
# elements in the bin: 12800
# 807
# elements in the bin: 12800
# 808
# elements in the bin: 12800
# 809
# elements in the bin: 12800
# 810
# elements in the bin: 12800
# 811
# elements in the bin: 12800
# 812
# elements in the bin: 12800
# 813
# elements in the bin: 12800
# 814
# elements in the bin: 12800
# 815
# elements in the bin: 12800
# 816
# elements in the bin: 12800
# 817
# elements in the bin: 12800
# 818
# elements in the bin: 12800
# 819
# elements in the bin: 12800
# 820
# elements in the bin: 12800
# 821
# elements in the bin: 12800
# 822
# elements in the bin: 12800
# 823
# elements in the bin: 12800
# 824
# elements in the bin: 12800
# 825
# elements in the bin: 12800
# 826
# elements in the bin: 12800
# 827
# elements in the bin: 12800
# 828
# elements in the bin: 12800
# 829
# elements in the bin: 12800
# 830
# elements in the bin: 12800
# 831
# elements in the bin: 12800
# 832
# elements in the bin: 12800
# 833
# elements in the bin: 12800
# 834
# elements in the bin: 12800
# 835
# elements in the bin: 12800
# 836
# elements in the bin: 12800
# 837
# elements in the bin: 12800
# 838
# elements in the bin: 12800
# 839
# elements in the bin: 12800
# 840
# elements in the bin: 12800
# 841
# elements in the bin: 12800
# 842
# elements in the bin: 12800
# 843
# elements in the bin: 12800
# 844
# elements in the bin: 12800
# 845
# elements in the bin: 12800
# 846
# elements in the bin: 12800
# 847
# elements in the bin: 12800
# 848
# elements in the bin: 12800
# 849
# elements in the bin: 12800
# 850
# elements in the bin: 12800
# 851
# elements in the bin: 12800
# 852
# elements in the bin: 12800
# 853
# elements in the bin: 12800
# 854
# elements in the bin: 12800
# 855
# elements in the bin: 12800
# 856
# elements in the bin: 12800
# 857
# elements in the bin: 12800
# 858
# elements in the bin: 12800
# 859
# elements in the bin: 12800
# 860
# elements in the bin: 12800
# 861
# elements in the bin: 12800
# 862
# elements in the bin: 12800
# 863
# elements in the bin: 12800
# 864
# elements in the bin: 12800
# 865
# elements in the bin: 12800
# 866
# elements in the bin: 12800
# 867
# elements in the bin: 12800
# 868
# elements in the bin: 12800
# 869
# elements in the bin: 12800
# 870
# elements in the bin: 12800
# 871
# elements in the bin: 12800
# 872
# elements in the bin: 12800
# 873
# elements in the bin: 12800
# 874
# elements in the bin: 12800
# 875
# elements in the bin: 12800
# 876
# elements in the bin: 12800
# 877
# elements in the bin: 12800
# 878
# elements in the bin: 12800
# 879
# elements in the bin: 12800
# 880
# elements in the bin: 12800
# 881
# elements in the bin: 12800
# 882
# elements in the bin: 12800
# 883
# elements in the bin: 12800
# 884
# elements in the bin: 12800
# 885
# elements in the bin: 12800
# 886
# elements in the bin: 12800
# 887
# elements in the bin: 12800
# 888
# elements in the bin: 12800
# 889
# elements in the bin: 12800
# 890
# elements in the bin: 12800
# 891
# elements in the bin: 12800
# 892
# elements in the bin: 12800
# 893
# elements in the bin: 12800
# 894
# elements in the bin: 12800
# 895
# elements in the bin: 12800
# 896
# elements in the bin: 12800
# 897
# elements in the bin: 12800
# 898
# elements in the bin: 12800
# 899
# elements in the bin: 12800
# 900
# elements in the bin: 12800
# 901
# elements in the bin: 12800
# 902
# elements in the bin: 12800
# 903
# elements in the bin: 12800
# 904
# elements in the bin: 12800
# 905
# elements in the bin: 12800
# 906
# elements in the bin: 12800
# 907
# elements in the bin: 12800
# 908
# elements in the bin: 12800
# 909
# elements in the bin: 12800
# 910
# elements in the bin: 12800
# 911
# elements in the bin: 12800
# 912
# elements in the bin: 12800
# 913
# elements in the bin: 12800
# 914
# elements in the bin: 12800
# 915
# elements in the bin: 12800
# 916
# elements in the bin: 12800
# 917
# elements in the bin: 12800
# 918
# elements in the bin: 12800
# 919
# elements in the bin: 12800
# 920
# elements in the bin: 12800
# 921
# elements in the bin: 12800
# 922
# elements in the bin: 12800
# 923
# elements in the bin: 12800
# 924
# elements in the bin: 12800
# 925
# elements in the bin: 12800
# 926
# elements in the bin: 12800
# 927
# elements in the bin: 12800
# 928
# elements in the bin: 12800
# 929
# elements in the bin: 12800
# 930
# elements in the bin: 12800
# 931
# elements in the bin: 12800
# 932
# elements in the bin: 12800
# 933
# elements in the bin: 12800
# 934
# elements in the bin: 12800
# 935
# elements in the bin: 12800
# 936
# elements in the bin: 12800
# 937
# elements in the bin: 12800
# 938
# elements in the bin: 12800
# 939
# elements in the bin: 12800
# 940
# elements in the bin: 12800
# 941
# elements in the bin: 12800
# 942
# elements in the bin: 12800
# 943
# elements in the bin: 12800
# 944
# elements in the bin: 12800
# 945
# elements in the bin: 12800
# 946
# elements in the bin: 12800
# 947
# elements in the bin: 12800
# 948
# elements in the bin: 12800
# 949
# elements in the bin: 12800
# 950
# elements in the bin: 12800
# 951
# elements in the bin: 12800
# 952
# elements in the bin: 12800
# 953
# elements in the bin: 12800
# 954
# elements in the bin: 12800
# 955
# elements in the bin: 12800
# 956
# elements in the bin: 12800
# 957
# elements in the bin: 12800
# 958
# elements in the bin: 12800
# 959
# elements in the bin: 12800
# 960
# elements in the bin: 12800
# 961
# elements in the bin: 12800
# 962
# elements in the bin: 12800
# 963
# elements in the bin: 12800
# 964
# elements in the bin: 12800
# 965
# elements in the bin: 12800
# 966
# elements in the bin: 12800
# 967
# elements in the bin: 12800
# 968
# elements in the bin: 12800
# 969
# elements in the bin: 12800
# 970
# elements in the bin: 12800
# 971
# elements in the bin: 12800
# 972
# elements in the bin: 12800
# 973
# elements in the bin: 12800
# 974
# elements in the bin: 12800
# 975
# elements in the bin: 12800
# 976
# elements in the bin: 12800
# 977
# elements in the bin: 12800
# 978
# elements in the bin: 12800
# 979
# elements in the bin: 12800
# 980
# elements in the bin: 12800
# 981
# elements in the bin: 12800
# 982
# elements in the bin: 12800
# 983
# elements in the bin: 12800
# 984
# elements in the bin: 12800
# 985
# elements in the bin: 12800
# 986
# elements in the bin: 12800
# 987
# elements in the bin: 12800
# 988
# elements in the bin: 12800
# 989
# elements in the bin: 12800
# 990
# elements in the bin: 12800
# 991
# elements in the bin: 12800
# 992
# elements in the bin: 12800
# 993
# elements in the bin: 12800
# 994
# elements in the bin: 12800
# 995
# elements in the bin: 12800
# 996
# elements in the bin: 12800
# 997
# elements in the bin: 12800
# 998
# elements in the bin: 12800
# 999
# elements in the bin: 12800
# 1000
# elements in the bin: 12800
# 1001
# elements in the bin: 12800
# 1002
# elements in the bin: 12800
# 1003
# elements in the bin: 12800
# 1004
# elements in the bin: 12800
# 1005
# elements in the bin: 12800
# 1006
# elements in the bin: 12800
# 1007
# elements in the bin: 12800
# 1008
# elements in the bin: 12800
# 1009
# elements in the bin: 12800
# 1010
# elements in the bin: 12800
# 1011
# elements in the bin: 12800
# 1012
# elements in the bin: 12800
# 1013
# elements in the bin: 12800
# 1014
# elements in the bin: 12800
# 1015
# elements in the bin: 12800
# 1016
# elements in the bin: 12800
# 1017
# elements in the bin: 12800
# 1018
# elements in the bin: 12800
# 1019
# elements in the bin: 12800
# 1020
# elements in the bin: 12800
# 1021
# elements in the bin: 12800
# 1022
# elements in the bin: 12800
# 1023
# elements in the bin: 12800
# 1024
# elements in the bin: 12800
# 1025
# elements in the bin: 12800
# 1026
# elements in the bin: 12800
# 1027
# elements in the bin: 12800
# 1028
# elements in the bin: 12800
# 1029
# elements in the bin: 12800
# 1030
# elements in the bin: 12800
# 1031
# elements in the bin: 12800
# 1032
# elements in the bin: 12800
# 1033
# elements in the bin: 12800
# 1034
# elements in the bin: 12800
# 1035
# elements in the bin: 12800
# 1036
# elements in the bin: 12800
# 1037
# elements in the bin: 12800
# 1038
# elements in the bin: 12800
# 1039
# elements in the bin: 12800
# 1040
# elements in the bin: 12800
# 1041
# elements in the bin: 12800
# 1042
# elements in the bin: 12800
# 1043
# elements in the bin: 12800
# 1044
# elements in the bin: 12800
# 1045
# elements in the bin: 12800
# 1046
# elements in the bin: 12800
# 1047
# elements in the bin: 12800
# 1048
# elements in the bin: 12800
# 1049
# elements in the bin: 12800
# 1050
# elements in the bin: 12800
# 1051
# elements in the bin: 12800
# 1052
# elements in the bin: 12800
# 1053
# elements in the bin: 12800
# 1054
# elements in the bin: 12800
# 1055
# elements in the bin: 12800
# 1056
# elements in the bin: 12800
# 1057
# elements in the bin: 12800
# 1058
# elements in the bin: 12800
# 1059
# elements in the bin: 12800
# 1060
# elements in the bin: 12800
# 1061
# elements in the bin: 12800
# 1062
# elements in the bin: 12800
# 1063
# elements in the bin: 12800
# 1064
# elements in the bin: 12800
# 1065
# elements in the bin: 12800
# 1066
# elements in the bin: 12800
# 1067
# elements in the bin: 12800
# 1068
# elements in the bin: 12800
# 1069
# elements in the bin: 12800
# 1070
# elements in the bin: 12800
# 1071
# elements in the bin: 12800
# 1072
# elements in the bin: 12800
# 1073
# elements in the bin: 12800
# 1074
# elements in the bin: 12800
# 1075
# elements in the bin: 12800
# 1076
# elements in the bin: 12800
# 1077
# elements in the bin: 12800
# 1078
# elements in the bin: 12800
# 1079
# elements in the bin: 12800
# 1080
# elements in the bin: 12800
# 1081
# elements in the bin: 12800
# 1082
# elements in the bin: 12800
# 1083
# elements in the bin: 12800
# 1084
# elements in the bin: 12800
# 1085
# elements in the bin: 12800
# 1086
# elements in the bin: 12800
# 1087
# elements in the bin: 12800
# 1088
# elements in the bin: 12800
# 1089
# elements in the bin: 12800
# 1090
# elements in the bin: 12800
# 1091
# elements in the bin: 12800
# 1092
# elements in the bin: 12800
# 1093
# elements in the bin: 12800
# 1094
# elements in the bin: 12800
# 1095
# elements in the bin: 12800
# 1096
# elements in the bin: 12800
# 1097
# elements in the bin: 12800
# 1098
# elements in the bin: 12800
# 1099
# elements in the bin: 12800
# 1100
# elements in the bin: 12800
# 1101
# elements in the bin: 12800
# 1102
# elements in the bin: 12800
# 1103
# elements in the bin: 12800
# 1104
# elements in the bin: 12800
# 1105
# elements in the bin: 12800
# 1106
# elements in the bin: 12800
# 1107
# elements in the bin: 12800
# 1108
# elements in the bin: 12800
# 1109
# elements in the bin: 12800
# 1110
# elements in the bin: 12800
# 1111
# elements in the bin: 12800
# 1112
# elements in the bin: 12800
# 1113
# elements in the bin: 12800
# 1114
# elements in the bin: 12800
# 1115
# elements in the bin: 12800
# 1116
# elements in the bin: 12800
# 1117
# elements in the bin: 12800
# 1118
# elements in the bin: 12800
# 1119
# elements in the bin: 12800
# 1120
# elements in the bin: 12800
# 1121
# elements in the bin: 12800
# 1122
# elements in the bin: 12800
# 1123
# elements in the bin: 12800
# 1124
# elements in the bin: 12800
# 1125
# elements in the bin: 12800
# 1126
# elements in the bin: 12800
# 1127
# elements in the bin: 12800
# 1128
# elements in the bin: 12800
# 1129
# elements in the bin: 12800
# 1130
# elements in the bin: 12800
# 1131
# elements in the bin: 12800
# 1132
# elements in the bin: 12800
# 1133
# elements in the bin: 12800
# 1134
# elements in the bin: 12800
# 1135
# elements in the bin: 12800
# 1136
# elements in the bin: 12800
# 1137
# elements in the bin: 12800
# 1138
# elements in the bin: 12800
# 1139
# elements in the bin: 12800
# 1140
# elements in the bin: 12800
# 1141
# elements in the bin: 12800
# 1142
# elements in the bin: 12800
# 1143
# elements in the bin: 12800
# 1144
# elements in the bin: 12800
# 1145
# elements in the bin: 12800
# 1146
# elements in the bin: 12800
# 1147
# elements in the bin: 12800
# 1148
# elements in the bin: 12800
# 1149
# elements in the bin: 12800
# 1150
# elements in the bin: 12800
# 1151
# elements in the bin: 12800
# 1152
# elements in the bin: 12800
# 1153
# elements in the bin: 12800
# 1154
# elements in the bin: 12800
# 1155
# elements in the bin: 12800
# 1156
# elements in the bin: 12800
# 1157
# elements in the bin: 12800
# 1158
# elements in the bin: 12800
# 1159
# elements in the bin: 12800
# 1160
# elements in the bin: 12800
# 1161
# elements in the bin: 12800
# 1162
# elements in the bin: 12800
# 1163
# elements in the bin: 12800
# 1164
# elements in the bin: 12800
# 1165
# elements in the bin: 12800
# 1166
# elements in the bin: 12800
# 1167
# elements in the bin: 12800
# 1168
# elements in the bin: 12800
# 1169
# elements in the bin: 12800
# 1170
# elements in the bin: 12800
# 1171
# elements in the bin: 12800
# 1172
# elements in the bin: 12800
# 1173
# elements in the bin: 12800
# 1174
# elements in the bin: 12800
# 1175
# elements in the bin: 12800
# 1176
# elements in the bin: 12800
# 1177
# elements in the bin: 12800
# 1178
# elements in the bin: 12800
# 1179
# elements in the bin: 12800
# 1180
# elements in the bin: 12800
# 1181
# elements in the bin: 12800
# 1182
# elements in the bin: 12800
# 1183
# elements in the bin: 12800
# 1184
# elements in the bin: 12800
# 1185
# elements in the bin: 12800
# 1186
# elements in the bin: 12800
# 1187
# elements in the bin: 12800
# 1188
# elements in the bin: 12800
# 1189
# elements in the bin: 12800
# 1190
# elements in the bin: 12800
# 1191
# elements in the bin: 12800
# 1192
# elements in the bin: 12800
# 1193
# elements in the bin: 12800
# 1194
# elements in the bin: 12800
# 1195
# elements in the bin: 12800
# 1196
# elements in the bin: 12800
# 1197
# elements in the bin: 12800
# 1198
# elements in the bin: 12800
# 1199
# elements in the bin: 12800
# 1200
# elements in the bin: 12800
# 1201
# elements in the bin: 12800
# 1202
# elements in the bin: 12800
# 1203
# elements in the bin: 12800
# 1204
# elements in the bin: 12800
# 1205
# elements in the bin: 12800
# 1206
# elements in the bin: 12800
# 1207
# elements in the bin: 12800
# 1208
# elements in the bin: 12800
# 1209
# elements in the bin: 12800
# 1210
# elements in the bin: 12800
# 1211
# elements in the bin: 12800
# 1212
# elements in the bin: 12800
# 1213
# elements in the bin: 12800
# 1214
# elements in the bin: 12800
# 1215
# elements in the bin: 12800
# 1216
# elements in the bin: 12800
# 1217
# elements in the bin: 12800
# 1218
# elements in the bin: 12800
# 1219
# elements in the bin: 12800
# 1220
# elements in the bin: 12800
# 1221
# elements in the bin: 12800
# 1222
# elements in the bin: 12800
# 1223
# elements in the bin: 12800
# 1224
# elements in the bin: 12800
# 1225
# elements in the bin: 12800
# 1226
# elements in the bin: 12800
# 1227
# elements in the bin: 12800
# 1228
# elements in the bin: 12800
# 1229
# elements in the bin: 12800
# 1230
# elements in the bin: 12800
# 1231
# elements in the bin: 12800
# 1232
# elements in the bin: 12800
# 1233
# elements in the bin: 12800
# 1234
# elements in the bin: 12800
# 1235
# elements in the bin: 12800
# 1236
# elements in the bin: 12800
# 1237
# elements in the bin: 12800
# 1238
# elements in the bin: 12800
# 1239
# elements in the bin: 12800
# 1240
# elements in the bin: 12800
# 1241
# elements in the bin: 12800
# 1242
# elements in the bin: 12800
# 1243
# elements in the bin: 12800
# 1244
# elements in the bin: 12800
# 1245
# elements in the bin: 12800
# 1246
# elements in the bin: 12800
# 1247
# elements in the bin: 12800
# 1248
# elements in the bin: 12800
# 1249
# elements in the bin: 12800
# 1250
# elements in the bin: 12800
# 1251
# elements in the bin: 12800
# 1252
# elements in the bin: 12800
# 1253
# elements in the bin: 12800
# 1254
# elements in the bin: 12800
# 1255
# elements in the bin: 12800
# 1256
# elements in the bin: 12800
# 1257
# elements in the bin: 12800
# 1258
# elements in the bin: 12800
# 1259
# elements in the bin: 12800
# 1260
# elements in the bin: 12800
# 1261
# elements in the bin: 12800
# 1262
# elements in the bin: 12800
# 1263
# elements in the bin: 12800
# 1264
# elements in the bin: 12800
# 1265
# elements in the bin: 12800
# 1266
# elements in the bin: 12800
# 1267
# elements in the bin: 12800
# 1268
# elements in the bin: 12800
# 1269
# elements in the bin: 12800
# 1270
# elements in the bin: 12800
# 1271
# elements in the bin: 12800
# 1272
# elements in the bin: 12800
# 1273
# elements in the bin: 12800
# 1274
# elements in the bin: 12800
# 1275
# elements in the bin: 12800
# 1276
# elements in the bin: 12800
# 1277
# elements in the bin: 12800
# 1278
# elements in the bin: 12800
# 1279
# elements in the bin: 12800
# 1280
# elements in the bin: 12800
# 1281
# elements in the bin: 12800
# 1282
# elements in the bin: 12800
# 1283
# elements in the bin: 12800
# 1284
# elements in the bin: 12800
# 1285
# elements in the bin: 12800
# 1286
# elements in the bin: 12800
# 1287
# elements in the bin: 12800
# 1288
# elements in the bin: 12800
# 1289
# elements in the bin: 12800
# 1290
# elements in the bin: 12800
# 1291
# elements in the bin: 12800
# 1292
# elements in the bin: 12800
# 1293
# elements in the bin: 12800
# 1294
# elements in the bin: 12800
# 1295
# elements in the bin: 12800
# 1296
# elements in the bin: 12800
# 1297
# elements in the bin: 12800
# 1298
# elements in the bin: 12800
# 1299
# elements in the bin: 12800
# 1300
# elements in the bin: 12800
# 1301
# elements in the bin: 12800
# 1302
# elements in the bin: 12800
# 1303
# elements in the bin: 12800
# 1304
# elements in the bin: 12800
# 1305
# elements in the bin: 12800
# 1306
# elements in the bin: 12800
# 1307
# elements in the bin: 12800
# 1308
# elements in the bin: 12800
# 1309
# elements in the bin: 12800
# 1310
# elements in the bin: 12800
# 1311
# elements in the bin: 12800
# 1312
# elements in the bin: 12800
# 1313
# elements in the bin: 12800
# 1314
# elements in the bin: 12800
# 1315
# elements in the bin: 12800
# 1316
# elements in the bin: 12800
# 1317
# elements in the bin: 12800
# 1318
# elements in the bin: 12800
# 1319
# elements in the bin: 12800
# 1320
# elements in the bin: 12800
# 1321
# elements in the bin: 12800
# 1322
# elements in the bin: 12800
# 1323
# elements in the bin: 12800
# 1324
# elements in the bin: 12800
# 1325
# elements in the bin: 12800
# 1326
# elements in the bin: 12800
# 1327
# elements in the bin: 12800
# 1328
# elements in the bin: 12800
# 1329
# elements in the bin: 12800
# 1330
# elements in the bin: 12800
# 1331
# elements in the bin: 12800
# 1332
# elements in the bin: 12800
# 1333
# elements in the bin: 12800
# 1334
# elements in the bin: 12800
# 1335
# elements in the bin: 12800
# 1336
# elements in the bin: 12800
# 1337
# elements in the bin: 12800
# 1338
# elements in the bin: 12800
# 1339
# elements in the bin: 12800
# 1340
# elements in the bin: 12800
# 1341
# elements in the bin: 12800
# 1342
# elements in the bin: 12800
# 1343
# elements in the bin: 12800
# 1344
# elements in the bin: 12800
# 1345
# elements in the bin: 12800
# 1346
# elements in the bin: 12800
# 1347
# elements in the bin: 12800
# 1348
# elements in the bin: 12800
# 1349
# elements in the bin: 12800
# 1350
# elements in the bin: 12800
# 1351
# elements in the bin: 12800
# 1352
# elements in the bin: 12800
# 1353
# elements in the bin: 12800
# 1354
# elements in the bin: 12800
# 1355
# elements in the bin: 12800
# 1356
# elements in the bin: 12800
# 1357
# elements in the bin: 12800
# 1358
# elements in the bin: 12800
# 1359
# elements in the bin: 12800
# 1360
# elements in the bin: 12800
# 1361
# elements in the bin: 12800
# 1362
# elements in the bin: 12800
# 1363
# elements in the bin: 12800
# 1364
# elements in the bin: 12800
# 1365
# elements in the bin: 12800
# 1366
# elements in the bin: 12800
# 1367
# elements in the bin: 12800
# 1368
# elements in the bin: 12800
# 1369
# elements in the bin: 12800
# 1370
# elements in the bin: 12800
# 1371
# elements in the bin: 12800
# 1372
# elements in the bin: 12800
# 1373
# elements in the bin: 12800
# 1374
# elements in the bin: 12800
# 1375
# elements in the bin: 12800
# 1376
# elements in the bin: 12800
# 1377
# elements in the bin: 12800
# 1378
# elements in the bin: 12800
# 1379
# elements in the bin: 12800
# 1380
# elements in the bin: 12800
# 1381
# elements in the bin: 12800
# 1382
# elements in the bin: 12800
# 1383
# elements in the bin: 12800
# 1384
# elements in the bin: 12800
# 1385
# elements in the bin: 12800
# 1386
# elements in the bin: 12800
# 1387
# elements in the bin: 12800
# 1388
# elements in the bin: 12800
# 1389
# elements in the bin: 12800
# 1390
# elements in the bin: 12800
# 1391
# elements in the bin: 12800
# 1392
# elements in the bin: 12800
# 1393
# elements in the bin: 12800
# 1394
# elements in the bin: 12800
# 1395
# elements in the bin: 12800
# 1396
# elements in the bin: 12800
# 1397
# elements in the bin: 12800
# 1398
# elements in the bin: 12800
# 1399
# elements in the bin: 12800
# 1400
# elements in the bin: 12800
# 1401
# elements in the bin: 12800
# 1402
# elements in the bin: 12800
# 1403
# elements in the bin: 12800
# 1404
# elements in the bin: 12800
# 1405
# elements in the bin: 12800
# 1406
# elements in the bin: 12800
# 1407
# elements in the bin: 12800
# 1408
# elements in the bin: 12800
# 1409
# elements in the bin: 12800
# 1410
# elements in the bin: 12800
# 1411
# elements in the bin: 12800
# 1412
# elements in the bin: 12800
# 1413
# elements in the bin: 12800
# 1414
# elements in the bin: 12800
# 1415
# elements in the bin: 12800
# 1416
# elements in the bin: 12800
# 1417
# elements in the bin: 12800
# 1418
# elements in the bin: 12800
# 1419
# elements in the bin: 12800
# 1420
# elements in the bin: 12800
# 1421
# elements in the bin: 12800
# 1422
# elements in the bin: 12800
# 1423
# elements in the bin: 12800
# 1424
# elements in the bin: 12800
# 1425
# elements in the bin: 12800
# 1426
# elements in the bin: 12800
# 1427
# elements in the bin: 12800
# 1428
# elements in the bin: 12800
# 1429
# elements in the bin: 12800
# 1430
# elements in the bin: 12800
# 1431
# elements in the bin: 12800
# 1432
# elements in the bin: 12800
# 1433
# elements in the bin: 12800
# 1434
# elements in the bin: 12800
# 1435
# elements in the bin: 12800
# 1436
# elements in the bin: 12800
# 1437
# elements in the bin: 12800
# 1438
# elements in the bin: 12800
# 1439
# elements in the bin: 12800
# 1440
# elements in the bin: 12800
# 1441
# elements in the bin: 12800
# 1442
# elements in the bin: 12800
# 1443
# elements in the bin: 12800
# 1444
# elements in the bin: 12800
# 1445
# elements in the bin: 12800
# 1446
# elements in the bin: 12800
# 1447
# elements in the bin: 12800
# 1448
# elements in the bin: 12800
# 1449
# elements in the bin: 12800
# 1450
# elements in the bin: 12800
# 1451
# elements in the bin: 12800
# 1452
# elements in the bin: 12800
# 1453
# elements in the bin: 12800
# 1454
# elements in the bin: 12800
# 1455
# elements in the bin: 12800
# 1456
# elements in the bin: 12800
# 1457
# elements in the bin: 12800
# 1458
# elements in the bin: 12800
# 1459
# elements in the bin: 12800
# 1460
# elements in the bin: 12800
# 1461
# elements in the bin: 12800
# 1462
# elements in the bin: 12800
# 1463
# elements in the bin: 12800
# 1464
# elements in the bin: 12800
# 1465
# elements in the bin: 12800
# 1466
# elements in the bin: 12800
# 1467
# elements in the bin: 12800
# 1468
# elements in the bin: 12800
# 1469
# elements in the bin: 12800
# 1470
# elements in the bin: 12800
# 1471
# elements in the bin: 12800
# 1472
# elements in the bin: 12800
# 1473
# elements in the bin: 12800
# 1474
# elements in the bin: 12800
# 1475
# elements in the bin: 12800
# 1476
# elements in the bin: 12800
# 1477
# elements in the bin: 12800
# 1478
# elements in the bin: 12800
# 1479
# elements in the bin: 12800
# 1480
# elements in the bin: 12800
# 1481
# elements in the bin: 12800
# 1482
# elements in the bin: 12800
# 1483
# elements in the bin: 12800
# 1484
# elements in the bin: 12800
# 1485
# elements in the bin: 12800
# 1486
# elements in the bin: 12800
# 1487
# elements in the bin: 12800
# 1488
# elements in the bin: 12800
# 1489
# elements in the bin: 12800
# 1490
# elements in the bin: 12800
# 1491
# elements in the bin: 12800
# 1492
# elements in the bin: 12800
# 1493
# elements in the bin: 12800
# 1494
# elements in the bin: 12800
# 1495
# elements in the bin: 12800
# 1496
# elements in the bin: 12800
# 1497
# elements in the bin: 12800
# 1498
# elements in the bin: 12800
# 1499
# elements in the bin: 12800
# 1500
# elements in the bin: 12800
# 1501
# elements in the bin: 12800
# 1502
# elements in the bin: 12800
# 1503
# elements in the bin: 12800
# 1504
# elements in the bin: 12800
# 1505
# elements in the bin: 12800
# 1506
# elements in the bin: 12800
# 1507
# elements in the bin: 12800
# 1508
# elements in the bin: 12800
# 1509
# elements in the bin: 12800
# 1510
# elements in the bin: 12800
# 1511
# elements in the bin: 12800
# 1512
# elements in the bin: 12800
# 1513
# elements in the bin: 12800
# 1514
# elements in the bin: 12800
# 1515
# elements in the bin: 12800
# 1516
# elements in the bin: 12800
# 1517
# elements in the bin: 12800
# 1518
# elements in the bin: 12800
# 1519
# elements in the bin: 12800
# 1520
# elements in the bin: 12800
# 1521
# elements in the bin: 12800
# 1522
# elements in the bin: 12800
# 1523
# elements in the bin: 12800
# 1524
# elements in the bin: 12800
# 1525
# elements in the bin: 12800
# 1526
# elements in the bin: 12800
# 1527
# elements in the bin: 12800
# 1528
# elements in the bin: 12800
# 1529
# elements in the bin: 12800
# 1530
# elements in the bin: 12800
# 1531
# elements in the bin: 12800
# 1532
# elements in the bin: 12800
# 1533
# elements in the bin: 12800
# 1534
# ...
# elements in the bin: 12800
# 99516
# elements in the bin: 12800
# 99517
# elements in the bin: 12800
# 99518
# elements in the bin: 12800
# 99519
# elements in the bin: 12800
# 99520
# elements in the bin: 12800
# 99521
# elements in the bin: 12800
# 99522
# elements in the bin: 12800
# 99523
# elements in the bin: 12800
# 99524
# elements in the bin: 12800
# 99525
# elements in the bin: 12800
# 99526
# elements in the bin: 12800
# 99527
# elements in the bin: 12800
# 99528
# elements in the bin: 12800
# 99529
# elements in the bin: 12800
# 99530
# elements in the bin: 12800
# 99531
# elements in the bin: 12800
# 99532
# elements in the bin: 12800
# 99533
# elements in the bin: 12800
# 99534
# elements in the bin: 12800
# 99535
# elements in the bin: 12800
# 99536
# elements in the bin: 12800
# 99537
# elements in the bin: 12800
# 99538
# elements in the bin: 12800
# 99539
# elements in the bin: 12800
# 99540
# elements in the bin: 12800
# 99541
# elements in the bin: 12800
# 99542
# elements in the bin: 12800
# 99543
# elements in the bin: 12800
# 99544
# elements in the bin: 12800
# 99545
# elements in the bin: 12800
# 99546
# elements in the bin: 12800
# 99547
# elements in the bin: 12800
# 99548
# elements in the bin: 12800
# 99549
# elements in the bin: 12800
# 99550
# elements in the bin: 12800
# 99551
# elements in the bin: 12800
# 99552
# elements in the bin: 12800
# 99553
# elements in the bin: 12800
# 99554
# elements in the bin: 12800
# 99555
# elements in the bin: 12800
# 99556
# elements in the bin: 12800
# 99557
# elements in the bin: 12800
# 99558
# elements in the bin: 12800
# 99559
# elements in the bin: 12800
# 99560
# elements in the bin: 12800
# 99561
# elements in the bin: 12800
# 99562
# elements in the bin: 12800
# 99563
# elements in the bin: 12800
# 99564
# elements in the bin: 12800
# 99565
# elements in the bin: 12800
# 99566
# elements in the bin: 12800
# 99567
# elements in the bin: 12800
# 99568
# elements in the bin: 12800
# 99569
# elements in the bin: 12800
# 99570
# elements in the bin: 12800
# 99571
# elements in the bin: 12800
# 99572
# elements in the bin: 12800
# 99573
# elements in the bin: 12800
# 99574
# elements in the bin: 12800
# 99575
# elements in the bin: 12800
# 99576
# elements in the bin: 12800
# 99577
# elements in the bin: 12800
# 99578
# elements in the bin: 12800
# 99579
# elements in the bin: 12800
# 99580
# elements in the bin: 12800
# 99581
# elements in the bin: 12800
# 99582
# elements in the bin: 12800
# 99583
# elements in the bin: 12800
# 99584
# elements in the bin: 12800
# 99585
# elements in the bin: 12800
# 99586
# elements in the bin: 12800
# 99587
# elements in the bin: 12800
# 99588
# elements in the bin: 12800
# 99589
# elements in the bin: 12800
# 99590
# elements in the bin: 12800
# 99591
# elements in the bin: 12800
# 99592
# elements in the bin: 12800
# 99593
# elements in the bin: 12800
# 99594
# elements in the bin: 12800
# 99595
# elements in the bin: 12800
# 99596
# elements in the bin: 12800
# 99597
# elements in the bin: 12800
# 99598
# elements in the bin: 12800
# 99599
# elements in the bin: 12800
# 99600
# elements in the bin: 12800
# 99601
# elements in the bin: 12800
# 99602
# elements in the bin: 12800
# 99603
# elements in the bin: 12800
# 99604
# elements in the bin: 12800
# 99605
# elements in the bin: 12800
# 99606
# elements in the bin: 12800
# 99607
# elements in the bin: 12800
# 99608
# elements in the bin: 12800
# 99609
# elements in the bin: 12800
# 99610
# elements in the bin: 12800
# 99611
# elements in the bin: 12800
# 99612
# elements in the bin: 12800
# 99613
# elements in the bin: 12800
# 99614
# elements in the bin: 12800
# 99615
# elements in the bin: 12800
# 99616
# elements in the bin: 12800
# 99617
# elements in the bin: 12800
# 99618
# elements in the bin: 12800
# 99619
# elements in the bin: 12800
# 99620
# elements in the bin: 12800
# 99621
# elements in the bin: 12800
# 99622
# elements in the bin: 12800
# 99623
# elements in the bin: 12800
# 99624
# elements in the bin: 12800
# 99625
# elements in the bin: 12800
# 99626
# elements in the bin: 12800
# 99627
# elements in the bin: 12800
# 99628
# elements in the bin: 12800
# 99629
# elements in the bin: 12800
# 99630
# elements in the bin: 12800
# 99631
# elements in the bin: 12800
# 99632
# elements in the bin: 12800
# 99633
# elements in the bin: 12800
# 99634
# elements in the bin: 12800
# 99635
# elements in the bin: 12800
# 99636
# elements in the bin: 12800
# 99637
# elements in the bin: 12800
# 99638
# elements in the bin: 12800
# 99639
# elements in the bin: 12800
# 99640
# elements in the bin: 12800
# 99641
# elements in the bin: 12800
# 99642
# elements in the bin: 12800
# 99643
# elements in the bin: 12800
# 99644
# elements in the bin: 12800
# 99645
# elements in the bin: 12800
# 99646
# elements in the bin: 12800
# 99647
# elements in the bin: 12800
# 99648
# elements in the bin: 12800
# 99649
# elements in the bin: 12800
# 99650
# elements in the bin: 12800
# 99651
# elements in the bin: 12800
# 99652
# elements in the bin: 12800
# 99653
# elements in the bin: 12800
# 99654
# elements in the bin: 12800
# 99655
# elements in the bin: 12800
# 99656
# elements in the bin: 12800
# 99657
# elements in the bin: 12800
# 99658
# elements in the bin: 12800
# 99659
# elements in the bin: 12800
# 99660
# elements in the bin: 12800
# 99661
# elements in the bin: 12800
# 99662
# elements in the bin: 12800
# 99663
# elements in the bin: 12800
# 99664
# elements in the bin: 12800
# 99665
# elements in the bin: 12800
# 99666
# elements in the bin: 12800
# 99667
# elements in the bin: 12800
# 99668
# elements in the bin: 12800
# 99669
# elements in the bin: 12800
# 99670
# elements in the bin: 12800
# 99671
# elements in the bin: 12800
# 99672
# elements in the bin: 12800
# 99673
# elements in the bin: 12800
# 99674
# elements in the bin: 12800
# 99675
# elements in the bin: 12800
# 99676
# elements in the bin: 12800
# 99677
# elements in the bin: 12800
# 99678
# elements in the bin: 12800
# 99679
# elements in the bin: 12800
# 99680
# elements in the bin: 12800
# 99681
# elements in the bin: 12800
# 99682
# elements in the bin: 12800
# 99683
# elements in the bin: 12800
# 99684
# elements in the bin: 12800
# 99685
# elements in the bin: 12800
# 99686
# elements in the bin: 12800
# 99687
# elements in the bin: 12800
# 99688
# elements in the bin: 12800
# 99689
# elements in the bin: 12800
# 99690
# elements in the bin: 12800
# 99691
# elements in the bin: 12800
# 99692
# elements in the bin: 12800
# 99693
# elements in the bin: 12800
# 99694
# elements in the bin: 12800
# 99695
# elements in the bin: 12800
# 99696
# elements in the bin: 12800
# 99697
# elements in the bin: 12800
# 99698
# elements in the bin: 12800
# 99699
# elements in the bin: 12800
# 99700
# elements in the bin: 12800
# 99701
# elements in the bin: 12800
# 99702
# elements in the bin: 12800
# 99703
# elements in the bin: 12800
# 99704
# elements in the bin: 12800
# 99705
# elements in the bin: 12800
# 99706
# elements in the bin: 12800
# 99707
# elements in the bin: 12800
# 99708
# elements in the bin: 12800
# 99709
# elements in the bin: 12800
# 99710
# elements in the bin: 12800
# 99711
# elements in the bin: 12800
# 99712
# elements in the bin: 12800
# 99713
# elements in the bin: 12800
# 99714
# elements in the bin: 12800
# 99715
# elements in the bin: 12800
# 99716
# elements in the bin: 12800
# 99717
# elements in the bin: 12800
# 99718
# elements in the bin: 12800
# 99719
# elements in the bin: 12800
# 99720
# elements in the bin: 12800
# 99721
# elements in the bin: 12800
# 99722
# elements in the bin: 12800
# 99723
# elements in the bin: 12800
# 99724
# elements in the bin: 12800
# 99725
# elements in the bin: 12800
# 99726
# elements in the bin: 12800
# 99727
# elements in the bin: 12800
# 99728
# elements in the bin: 12800
# 99729
# elements in the bin: 12800
# 99730
# elements in the bin: 12800
# 99731
# elements in the bin: 12800
# 99732
# elements in the bin: 12800
# 99733
# elements in the bin: 12800
# 99734
# elements in the bin: 12800
# 99735
# elements in the bin: 12800
# 99736
# elements in the bin: 12800
# 99737
# elements in the bin: 12800
# 99738
# elements in the bin: 12800
# 99739
# elements in the bin: 12800
# 99740
# elements in the bin: 12800
# 99741
# elements in the bin: 12800
# 99742
# elements in the bin: 12800
# 99743
# elements in the bin: 12800
# 99744
# elements in the bin: 12800
# 99745
# elements in the bin: 12800
# 99746
# elements in the bin: 12800
# 99747
# elements in the bin: 12800
# 99748
# elements in the bin: 12800
# 99749
# elements in the bin: 12800
# 99750
# elements in the bin: 12800
# 99751
# elements in the bin: 12800
# 99752
# elements in the bin: 12800
# 99753
# elements in the bin: 12800
# 99754
# elements in the bin: 12800
# 99755
# elements in the bin: 12800
# 99756
# elements in the bin: 12800
# 99757
# elements in the bin: 12800
# 99758
# elements in the bin: 12800
# 99759
# elements in the bin: 12800
# 99760
# elements in the bin: 12800
# 99761
# elements in the bin: 12800
# 99762
# elements in the bin: 12800
# 99763
# elements in the bin: 12800
# 99764
# elements in the bin: 12800
# 99765
# elements in the bin: 12800
# 99766
# elements in the bin: 12800
# 99767
# elements in the bin: 12800
# 99768
# elements in the bin: 12800
# 99769
# elements in the bin: 12800
# 99770
# elements in the bin: 12800
# 99771
# elements in the bin: 12800
# 99772
# elements in the bin: 12800
# 99773
# elements in the bin: 12800
# 99774
# elements in the bin: 12800
# 99775
# elements in the bin: 12800
# 99776
# elements in the bin: 12800
# 99777
# elements in the bin: 12800
# 99778
# elements in the bin: 12800
# 99779
# elements in the bin: 12800
# 99780
# elements in the bin: 12800
# 99781
# elements in the bin: 12800
# 99782
# elements in the bin: 12800
# 99783
# elements in the bin: 12800
# 99784
# elements in the bin: 12800
# 99785
# elements in the bin: 12800
# 99786
# elements in the bin: 12800
# 99787
# elements in the bin: 12800
# 99788
# elements in the bin: 12800
# 99789
# elements in the bin: 12800
# 99790
# elements in the bin: 12800
# 99791
# elements in the bin: 12800
# 99792
# elements in the bin: 12800
# 99793
# elements in the bin: 12800
# 99794
# elements in the bin: 12800
# 99795
# elements in the bin: 12800
# 99796
# elements in the bin: 12800
# 99797
# elements in the bin: 12800
# 99798
# elements in the bin: 12800
# 99799
# elements in the bin: 12800
# 99800
# elements in the bin: 12800
# 99801
# elements in the bin: 12800
# 99802
# elements in the bin: 12800
# 99803
# elements in the bin: 12800
# 99804
# elements in the bin: 12800
# 99805
# elements in the bin: 12800
# 99806
# elements in the bin: 12800
# 99807
# elements in the bin: 12800
# 99808
# elements in the bin: 12800
# 99809
# elements in the bin: 12800
# 99810
# elements in the bin: 12800
# 99811
# elements in the bin: 12800
# 99812
# elements in the bin: 12800
# 99813
# elements in the bin: 12800
# 99814
# elements in the bin: 12800
# 99815
# elements in the bin: 12800
# 99816
# elements in the bin: 12800
# 99817
# elements in the bin: 12800
# 99818
# elements in the bin: 12800
# 99819
# elements in the bin: 12800
# 99820
# elements in the bin: 12800
# 99821
# elements in the bin: 12800
# 99822
# elements in the bin: 12800
# 99823
# elements in the bin: 12800
# 99824
# elements in the bin: 12800
# 99825
# elements in the bin: 12800
# 99826
# elements in the bin: 12800
# 99827
# elements in the bin: 12800
# 99828
# elements in the bin: 12800
# 99829
# elements in the bin: 12800
# 99830
# elements in the bin: 12800
# 99831
# elements in the bin: 12800
# 99832
# elements in the bin: 12800
# 99833
# elements in the bin: 12800
# 99834
# elements in the bin: 12800
# 99835
# elements in the bin: 12800
# 99836
# elements in the bin: 12800
# 99837
# elements in the bin: 12800
# 99838
# elements in the bin: 12800
# 99839
# elements in the bin: 12800
# 99840
# elements in the bin: 12800
# 99841
# elements in the bin: 12800
# 99842
# elements in the bin: 12800
# 99843
# elements in the bin: 12800
# 99844
# elements in the bin: 12800
# 99845
# elements in the bin: 12800
# 99846
# elements in the bin: 12800
# 99847
# elements in the bin: 12800
# 99848
# elements in the bin: 12800
# 99849
# elements in the bin: 12800
# 99850
# elements in the bin: 12800
# 99851
# elements in the bin: 12800
# 99852
# elements in the bin: 12800
# 99853
# elements in the bin: 12800
# 99854
# elements in the bin: 12800
# 99855
# elements in the bin: 12800
# 99856
# elements in the bin: 12800
# 99857
# elements in the bin: 12800
# 99858
# elements in the bin: 12800
# 99859
# elements in the bin: 12800
# 99860
# elements in the bin: 12800
# 99861
# elements in the bin: 12800
# 99862
# elements in the bin: 12800
# 99863
# elements in the bin: 12800
# 99864
# elements in the bin: 12800
# 99865
# elements in the bin: 12800
# 99866
# elements in the bin: 12800
# 99867
# elements in the bin: 12800
# 99868
# elements in the bin: 12800
# 99869
# elements in the bin: 12800
# 99870
# elements in the bin: 12800
# 99871
# elements in the bin: 12800
# 99872
# elements in the bin: 12800
# 99873
# elements in the bin: 12800
# 99874
# elements in the bin: 12800
# 99875
# elements in the bin: 12800
# 99876
# elements in the bin: 12800
# 99877
# elements in the bin: 12800
# 99878
# elements in the bin: 12800
# 99879
# elements in the bin: 12800
# 99880
# elements in the bin: 12800
# 99881
# elements in the bin: 12800
# 99882
# elements in the bin: 12800
# 99883
# elements in the bin: 12800
# 99884
# elements in the bin: 12800
# 99885
# elements in the bin: 12800
# 99886
# elements in the bin: 12800
# 99887
# elements in the bin: 12800
# 99888
# elements in the bin: 12800
# 99889
# elements in the bin: 12800
# 99890
# elements in the bin: 12800
# 99891
# elements in the bin: 12800
# 99892
# elements in the bin: 12800
# 99893
# elements in the bin: 12800
# 99894
# elements in the bin: 12800
# 99895
# elements in the bin: 12800
# 99896
# elements in the bin: 12800
# 99897
# elements in the bin: 12800
# 99898
# elements in the bin: 12800
# 99899
# elements in the bin: 12800
# 99900
# elements in the bin: 12800
# 99901
# elements in the bin: 12800
# 99902
# elements in the bin: 12800
# 99903
# elements in the bin: 12800
# 99904
# elements in the bin: 12800
# 99905
# elements in the bin: 12800
# 99906
# elements in the bin: 12800
# 99907
# elements in the bin: 12800
# 99908
# elements in the bin: 12800
# 99909
# elements in the bin: 12800
# 99910
# elements in the bin: 12800
# 99911
# elements in the bin: 12800
# 99912
# elements in the bin: 12800
# 99913
# elements in the bin: 12800
# 99914
# elements in the bin: 12800
# 99915
# elements in the bin: 12800
# 99916
# elements in the bin: 12800
# 99917
# elements in the bin: 12800
# 99918
# elements in the bin: 12800
# 99919
# elements in the bin: 12800
# 99920
# elements in the bin: 12800
# 99921
# elements in the bin: 12800
# 99922
# elements in the bin: 12800
# 99923
# elements in the bin: 12800
# 99924
# elements in the bin: 12800
# 99925
# elements in the bin: 12800
# 99926
# elements in the bin: 12800
# 99927
# elements in the bin: 12800
# 99928
# elements in the bin: 12800
# 99929
# elements in the bin: 12800
# 99930
# elements in the bin: 12800
# 99931
# elements in the bin: 12800
# 99932
# elements in the bin: 12800
# 99933
# elements in the bin: 12800
# 99934
# elements in the bin: 12800
# 99935
# elements in the bin: 12800
# 99936
# elements in the bin: 12800
# 99937
# elements in the bin: 12800
# 99938
# elements in the bin: 12800
# 99939
# elements in the bin: 12800
# 99940
# elements in the bin: 12800
# 99941
# elements in the bin: 12800
# 99942
# elements in the bin: 12800
# 99943
# elements in the bin: 12800
# 99944
# elements in the bin: 12800
# 99945
# elements in the bin: 12800
# 99946
# elements in the bin: 12800
# 99947
# elements in the bin: 12800
# 99948
# elements in the bin: 12800
# 99949
# elements in the bin: 12800
# 99950
# elements in the bin: 12800
# 99951
# elements in the bin: 12800
# 99952
# elements in the bin: 12800
# 99953
# elements in the bin: 12800
# 99954
# elements in the bin: 12800
# 99955
# elements in the bin: 12800
# 99956
# elements in the bin: 12800
# 99957
# elements in the bin: 12800
# 99958
# elements in the bin: 12800
# 99959
# elements in the bin: 12800
# 99960
# elements in the bin: 12800
# 99961
# elements in the bin: 12800
# 99962
# elements in the bin: 12800
# 99963
# elements in the bin: 12800
# 99964
# elements in the bin: 12800
# 99965
# elements in the bin: 12800
# 99966
# elements in the bin: 12800
# 99967
# elements in the bin: 12800
# 99968
# elements in the bin: 12800
# 99969
# elements in the bin: 12800
# 99970
# elements in the bin: 12800
# 99971
# elements in the bin: 12800
# 99972
# elements in the bin: 12800
# 99973
# elements in the bin: 12800
# 99974
# elements in the bin: 12800
# 99975
# elements in the bin: 12800
# 99976
# elements in the bin: 12800
# 99977
# elements in the bin: 12800
# 99978
# elements in the bin: 12800
# 99979
# elements in the bin: 12800
# 99980
# elements in the bin: 12800
# 99981
# elements in the bin: 12800
# 99982
# elements in the bin: 12800
# 99983
# elements in the bin: 12800
# 99984
# elements in the bin: 12800
# 99985
# elements in the bin: 12800
# 99986
# elements in the bin: 12800
# 99987
# elements in the bin: 12800
# 99988
# elements in the bin: 12800
# 99989
# elements in the bin: 12800
# 99990
# elements in the bin: 12800
# 99991
# elements in the bin: 12800
# 99992
# elements in the bin: 12800
# 99993
# elements in the bin: 12800
# 99994
# elements in the bin: 12800
# 99995
# elements in the bin: 12800
# 99996
# elements in the bin: 12800
# 99997
# elements in the bin: 12800
# 99998
# elements in the bin: 12800
# 99999
# elements in the bin: 12799
