# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score

# %%
bins=200
df_bins = pd.read_csv('../binning_real_data_q/df_bins_Dalkara_IM_%dbins.csv'%bins, index_col=0)

a,b = 1e-4,1e3

plt.figure(figsize=(4,3.8),facecolor='white')
ax = plt.subplot(111)
x = df_bins['mean_lambda']
y = df_bins['mean_count']
plt.scatter(x,y,marker='o')
plt.plot([a,b],[a,b],linestyle='--', color='red')
plt.xscale('log')
plt.yscale('log')
plt.yticks([1e-4, 1e-2, 1e0, 1e2],fontsize=15); plt.minorticks_off()
plt.xticks(fontsize=15)
plt.xlim(1e-4,1e3)
plt.ylim(1e-4,1e3)
ax.spines[['right', 'top']].set_visible(False)
plt.tight_layout()
plt.savefig('Dalkara_count_vs_lambda.png', dpi=1200)

# %%
bins=80
df_bins = pd.read_csv('../binning_real_data_q/df_bins_Byrne_IM_%dbins.csv'%bins, index_col=0)

a,b = 1e-4,1e3

plt.figure(figsize=(4,3.8),facecolor='white')
ax = plt.subplot(111)
x = df_bins['mean_lambda']
y = df_bins['mean_count']
plt.scatter(x,y,marker='o')
plt.plot([a,b],[a,b],linestyle='--', color='red')
plt.xscale('log')
plt.yscale('log')
plt.yticks([1e-4, 1e-2, 1e0, 1e2],fontsize=15); plt.minorticks_off()
plt.xticks(fontsize=15)
plt.xlim(1e-4,1e3)
plt.ylim(1e-4,1e3)
ax.spines[['right', 'top']].set_visible(False)
plt.tight_layout()
plt.savefig('Byrne_count_vs_lambda.png', dpi=1200)

# %%
bins=200
df_bins = pd.read_csv('../binning_real_data_q/df_bins_Dalkara_IM_%dbins.csv'%bins, index_col=0)

a, b = 1e-4, 1e3
c, d = 1e-4, 1e6

plt.figure(figsize=(4,3.8),facecolor='white')
ax = plt.subplot(111)
x = df_bins['mean_count']
y = df_bins['var_count']
plt.scatter(x,y,marker='o')
plt.plot([a,b],[a,b],linestyle='--', color='red')
plt.xscale('log')
plt.yscale('log')
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.ylim(c,d)
plt.xlim(a,b)
ax.spines[['right', 'top']].set_visible(False)
plt.tight_layout()
plt.savefig('Dalkara_var_vs_mean.png', dpi=1200)

# %%
bins=80
df_bins = pd.read_csv('../binning_real_data_q/df_bins_Byrne_IM_%dbins.csv'%bins, index_col=0)

a, b = 1e-4, 1e3
c, d = 1e-4, 1e6

plt.figure(figsize=(4,3.8),facecolor='white')
ax = plt.subplot(111)
x = df_bins['mean_count']
y = df_bins['var_count']
plt.scatter(x,y,marker='o')
plt.plot([a,b],[a,b],linestyle='--', color='red')
plt.xscale('log')
plt.yscale('log')
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlim(a,b)
plt.ylim(c,d)
ax.spines[['right', 'top']].set_visible(False)
plt.tight_layout()
plt.savefig('Byrne_var_vs_mean.png', dpi=1200)

# %%
bins=80
df_bins = pd.read_csv('../binning_real_data_q/df_bins_Byrne_IM_%dbins.csv'%bins, index_col=0)

a, b = 2e-4, 1e0
c, d = 2e-4, 1e1

plt.figure(figsize=(4,3.8),facecolor='white')
ax = plt.subplot(111)
x = df_bins['mean_count']
y = df_bins['var_count']
plt.scatter(x,y,marker='o')
plt.plot([a,b],[a,b],linestyle='--', color='red')

plt.xscale('log')
plt.yscale('log')
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlim(a,b)
plt.ylim(c,d)
ax.spines[['right', 'top']].set_visible(False)
plt.tight_layout()
plt.savefig('Byrne_var_vs_mean_noscale.png', dpi=1200)

# %% [markdown]
# ## Araya

# %%
replicate = 'T0_rep2'

plt.figure(figsize=(4,3.8),facecolor='white')
ax = plt.subplot(111)

a, b = 1e-10, 1e2
c, d = 1e-10, 1e3

for ham_dist in [2,3,4,5,6,7,8]:
    df_bins = pd.read_csv('../binning_Araya_data_q/df_bins_Araya_%s_ham%d.csv'%(replicate, ham_dist), index_col=0)
    x = df_bins['mean_lambda']
    y = df_bins['mean_count']
    plt.scatter(x,y,marker='.')

plt.plot([a,b],[a,b],linestyle='--', color='red')

plt.xscale('log')
plt.yscale('log')
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlim(a,b)
plt.ylim(c,d)
ax.spines[['right', 'top']].set_visible(False)
plt.tight_layout()
plt.savefig('Araya_count_vs_lambda_%s_noscale.png'%replicate, dpi=1200)

# %%
replicate = 'T0_rep2'

plt.figure(figsize=(4,3.8),facecolor='white')
ax = plt.subplot(111)

a, b = 1e-10, 1e2
c, d = 1e-10, 1e3

for ham_dist in [2,3,4,5,6,7,8]:
    df_bins = pd.read_csv('../binning_Araya_data_q/df_bins_Araya_%s_ham%d.csv'%(replicate, ham_dist), index_col=0)
    x = df_bins['mean_count']
    y = df_bins['var_count']
    plt.scatter(x,y,marker='.')

plt.plot([a,b],[a,b],linestyle='--', color='red')

plt.xscale('log')
plt.yscale('log')
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlim(a,b)
plt.ylim(c,d)
ax.spines[['right', 'top']].set_visible(False)
plt.tight_layout()
plt.savefig('Araya_var_vs_mean_%s_noscale.png'%replicate, dpi=1200)

# %%
#inset
replicate = 'T0_rep1'

plt.figure(figsize=(1.3,1.3))
ax = plt.subplot(111)

a, b = 1e-10, 1e2
c, d = 1e-10, 1e3

for ham_dist in [2,3,4,5,6,7,8]:
    df_bins = pd.read_csv('../binning_Araya_data_q/df_bins_Araya_%s_ham%d.csv'%(replicate, ham_dist), index_col=0)
    x = df_bins['mean_count']
    y = df_bins['F']
    plt.scatter(x,y,marker='.')

plt.hlines(1,a,b,linestyle='--', color='red')

plt.xscale('log')
plt.yscale('log')
#plt.xticks(fontsize=15)
plt.yticks([1,2,3,4,6],[1,2,3,4,6])
#plt.xlim(a,b)
#plt.ylim(c,d)
#ax.spines[['right', 'top']].set_visible(False)
plt.tight_layout()
plt.savefig('Araya_F_vs_mean_%s_noscale.png'%replicate, dpi=1200)
