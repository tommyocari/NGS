# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../scRNAseq_data/df.csv',index_col=0).iloc[[0,2,4,5,6,7,8,9,10]].sort_values('sat_frac')

plt.figure(figsize=(5,3.8),facecolor='white')
ax = plt.subplot(111)

D = np.logspace(4,10,150)
N = np.linspace(1e6,1e8,10)

plt.plot(D,np.sqrt(D/11), color='black', linewidth=.2)
plt.scatter(10*N, np.sqrt(10*N/11), color='black')

for n in N:
    plt.plot(x, np.sqrt(x/(1+x/n)))

        
plt.xscale('log')
#plt.yscale('log')
plt.xlim(1e4,1e10)
plt.ylim(0,1e4)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
ax.spines[['right', 'top']].set_visible(False)
plt.tight_layout()
